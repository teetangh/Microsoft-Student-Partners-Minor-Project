# %% [markdown]
# <b>Problem statement:
#
# Given profiles representing fictional customers from an e-commerce company. The profiles contain information about the customer, their orders, their transactions ,what payment methods they used and whether the customer is fraudulent or not.
# We need to predict the given customer is fraudulent or not based on the above factors</b>

# %% [markdown]
# <h2>Loading and parsing Json file</h2>

# %%
import json
data = []
with open('customersdata.json') as f:
    for line in f:
        data.append(json.loads(line))
for item in data:
    print(item['customer']['customerEmail'],': paymentMethods-->',len(item['paymentMethods']),'transactions-->',(len(item['transactions'])),'orders-->',len(item['orders']))
# Out:
# josephhoward@yahoo.com : paymentMethods--> 1 transactions--> 2 orders--> 2
# evansjeffery@yahoo.com : paymentMethods--> 7 transactions--> 3 orders--> 3
# andersonwilliam@yahoo.com : paymentMethods--> 2 transactions--> 5 orders--> 3
# rubenjuarez@yahoo.com : paymentMethods--> 1 transactions--> 3 orders--> 3
# uchen@malone.com : paymentMethods--> 6 transactions--> 7 orders--> 7
# robinsoncynthia@dunn.com : paymentMethods--> 2 transactions--> 1 orders--> 1
# samuel15@saunders-rhodes.com : paymentMethods--> 2 transactions--> 2 orders--> 1
# johnlowery@gmail.com : paymentMethods--> 2 transactions--> 6 orders--> 5
# jameslandry@rodriguez.com : paymentMethods--> 1 transactions--> 5 orders--> 2
# ubranch@rivera-parker.info : paymentMethods--> 1 transactions--> 0 orders--> 0
# bowenwilliam@yahoo.com : paymentMethods--> 1 transactions--> 6 orders--> 5
# ksummers@hotmail.com : paymentMethods--> 4 transactions--> 7 orders--> 5
# christineklein@wright-boyd.org : paymentMethods--> 3 transactions--> 4 orders--> 4
# meganwalters@chavez.com : paymentMethods--> 1 transactions--> 4 orders--> 2
# caleb94@sutton.info : paymentMethods--> 2 transactions--> 5 orders--> 5
# gonzalesjackson@gmail.com : paymentMethods--> 1 transactions--> 4 orders--> 4
# dana09@yahoo.com : paymentMethods--> 2 transactions--> 6 orders--> 3
# alec27@bell.com : paymentMethods--> 2 transactions--> 6 orders--> 4
# juliecook@hotmail.com : paymentMethods--> 1 transactions--> 2 orders--> 2
# meganberry@clark.biz : paymentMethods--> 2 transactions--> 5 orders--> 4
# psantiago@nelson.net : paymentMethods--> 1 transactions--> 1 orders--> 1
# harrisnicholas@mitchell-hancock.com : paymentMethods--> 2 transactions--> 6 orders--> 4
# davismike@hotmail.com : paymentMethods--> 1 transactions--> 4 orders--> 3
# guerramichael@hotmail.com : paymentMethods--> 1 transactions--> 0 orders--> 0
# natalie98@yahoo.com : paymentMethods--> 1 transactions--> 1 orders--> 1
# karen54@mullins.biz : paymentMethods--> 2 transactions--> 8 orders--> 5
# avaldez@gmail.com : paymentMethods--> 1 transactions--> 2 orders--> 1
# blackjoel@wright.com : paymentMethods--> 1 transactions--> 6 orders--> 5
# abigail08@yahoo.com : paymentMethods--> 2 transactions--> 5 orders--> 3
# catherine64@gmail.com : paymentMethods--> 6 transactions--> 5 orders--> 4
# romerolauren@hotmail.com : paymentMethods--> 1 transactions--> 2 orders--> 2
# qramsey@hotmail.com : paymentMethods--> 2 transactions--> 6 orders--> 5
# 9es7t@u6n7x : paymentMethods--> 1 transactions--> 2 orders--> 1
# ypruitt@hotmail.com : paymentMethods--> 3 transactions--> 4 orders--> 4
# zbennett@frazier.com : paymentMethods--> 0 transactions--> 0 orders--> 0
# aweaver@yahoo.com : paymentMethods--> 1 transactions--> 1 orders--> 1
# richard05@hanson-key.org : paymentMethods--> 1 transactions--> 1 orders--> 1
# paul86@hotmail.com : paymentMethods--> 1 transactions--> 2 orders--> 1
# xwang@white.com : paymentMethods--> 0 transactions--> 0 orders--> 0
# mark02@young.com : paymentMethods--> 2 transactions--> 5 orders--> 4
# johnlowery@gmail.com : paymentMethods--> 1 transactions--> 0 orders--> 0
# smithtiffany@davis-perkins.com : paymentMethods--> 1 transactions--> 0 orders--> 0
# brandon58@conner.com : paymentMethods--> 1 transactions--> 8 orders--> 3
# knichols@gmail.com : paymentMethods--> 1 transactions--> 0 orders--> 0
# gsimpson@cox.org : paymentMethods--> 0 transactions--> 0 orders--> 0
# johnlowery@gmail.com : paymentMethods--> 1 transactions--> 3 orders--> 2
# jamescampbell@randall-pacheco.biz : paymentMethods--> 2 transactions--> 7 orders--> 3
# johnsonjennifer@yahoo.com : paymentMethods--> 0 transactions--> 0 orders--> 0
# briana34@gmail.com : paymentMethods--> 2 transactions--> 7 orders--> 5
# jonesandrea@gray.biz : paymentMethods--> 1 transactions--> 3 orders--> 3
# kristina41@gmail.com : paymentMethods--> 3 transactions--> 7 orders--> 6
# whodges@yahoo.com : paymentMethods--> 1 transactions--> 0 orders--> 0
# nolanalec@yahoo.com : paymentMethods--> 3 transactions--> 5 orders--> 4
# spencer77@reid.com : paymentMethods--> 3 transactions--> 5 orders--> 2
# zthomas@gmail.com : paymentMethods--> 0 transactions--> 0 orders--> 0
# uguzman@yahoo.com : paymentMethods--> 1 transactions--> 1 orders--> 1
# ssmith@levine-harmon.biz : paymentMethods--> 2 transactions--> 8 orders--> 5
# feliciabrown@gmail.com : paymentMethods--> 1 transactions--> 1 orders--> 1
# dianacook@gmail.com : paymentMethods--> 1 transactions--> 3 orders--> 2
# cookbenjamin@hotmail.com : paymentMethods--> 1 transactions--> 6 orders--> 4
# joserowland@jones.com : paymentMethods--> 6 transactions--> 4 orders--> 4
# pattersonphilip@yahoo.com : paymentMethods--> 2 transactions--> 4 orders--> 4
# hj8maoy@1jcfcxs7 : paymentMethods--> 2 transactions--> 6 orders--> 5
# finleybrianna@yahoo.com : paymentMethods--> 1 transactions--> 7 orders--> 4
# suzanne21@gmail.com : paymentMethods--> 2 transactions--> 5 orders--> 3
# johnlowery@gmail.com : paymentMethods--> 1 transactions--> 7 orders--> 5
# kristaavery@lewis-baird.com : paymentMethods--> 3 transactions--> 1 orders--> 1
# dana23@lawrence.net : paymentMethods--> 1 transactions--> 0 orders--> 0
# cathy42@gibson.com : paymentMethods--> 15 transactions--> 3 orders--> 3
# michelleherrera@day.info : paymentMethods--> 1 transactions--> 6 orders--> 4
# brockmatthew@hotmail.com : paymentMethods--> 0 transactions--> 0 orders--> 0
# ijuarez@yahoo.com : paymentMethods--> 2 transactions--> 3 orders--> 3
# hughesjonathan@pena.org : paymentMethods--> 3 transactions--> 7 orders--> 5
# anthony04@gmail.com : paymentMethods--> 1 transactions--> 2 orders--> 2
# mgould@yahoo.com : paymentMethods--> 2 transactions--> 5 orders--> 4
# bakersydney@gmail.com : paymentMethods--> 1 transactions--> 5 orders--> 3
# kevinreyes@johnston.net : paymentMethods--> 1 transactions--> 0 orders--> 0
# udavis@clark.com : paymentMethods--> 1 transactions--> 3 orders--> 3
# nancymayo@brown.com : paymentMethods--> 2 transactions--> 7 orders--> 6
# johnlowery@gmail.com : paymentMethods--> 1 transactions--> 2 orders--> 2
# warrenedward@arnold.com : paymentMethods--> 14 transactions--> 4 orders--> 4
# rbolton@hotmail.com : paymentMethods--> 3 transactions--> 5 orders--> 4
# michael57@oconnor.com : paymentMethods--> 2 transactions--> 0 orders--> 0
# jonathan99@stafford.org : paymentMethods--> 1 transactions--> 2 orders--> 2
# lleonard@turner-fleming.com : paymentMethods--> 1 transactions--> 11 orders--> 8
# whitedavid@jones-lloyd.org : paymentMethods--> 4 transactions--> 5 orders--> 5
# grace99@wright.com : paymentMethods--> 1 transactions--> 0 orders--> 0
# tayloreric@gmail.com : paymentMethods--> 2 transactions--> 4 orders--> 3
# shelby24@hotmail.com : paymentMethods--> 2 transactions--> 5 orders--> 4
# cindydelgado@gmail.com : paymentMethods--> 1 transactions--> 4 orders--> 4
# brittanydean@hotmail.com : paymentMethods--> 1 transactions--> 6 orders--> 4
# watkinscaroline@lewis-haas.com : paymentMethods--> 1 transactions--> 2 orders--> 2
# marissacollins@mckinney.com : paymentMethods--> 1 transactions--> 6 orders--> 5
# craig83@rasmussen-alvarado.com : paymentMethods--> 13 transactions--> 2 orders--> 2
# thernandez@johnson-quinn.com : paymentMethods--> 1 transactions--> 2 orders--> 2
# emilyroberts@hotmail.com : paymentMethods--> 1 transactions--> 2 orders--> 2
# ukline@spears.biz : paymentMethods--> 3 transactions--> 0 orders--> 0
# vmiller@hotmail.com : paymentMethods--> 1 transactions--> 10 orders--> 8
# david45@gmail.com : paymentMethods--> 5 transactions--> 10 orders--> 8
# fdavis@wolfe-brown.com : paymentMethods--> 3 transactions--> 3 orders--> 3
# kathleenlee@yahoo.com : paymentMethods--> 3 transactions--> 6 orders--> 4
# benjamin19@gmail.com : paymentMethods--> 2 transactions--> 4 orders--> 3
# mtrevino@gutierrez.net : paymentMethods--> 4 transactions--> 1 orders--> 1
# tmcpherson@wright.com : paymentMethods--> 1 transactions--> 13 orders--> 8
# wdelacruz@yahoo.com : paymentMethods--> 1 transactions--> 4 orders--> 4
# brooksdustin@knight.info : paymentMethods--> 2 transactions--> 1 orders--> 1
# ybrown@gmail.com : paymentMethods--> 3 transactions--> 5 orders--> 4
# vreyes@cruz.info : paymentMethods--> 1 transactions--> 1 orders--> 1
# 3fooiar@6eph : paymentMethods--> 1 transactions--> 0 orders--> 0
# nicolekelly@hotmail.com : paymentMethods--> 1 transactions--> 1 orders--> 1
# barronelizabeth@singh.org : paymentMethods--> 2 transactions--> 5 orders--> 4
# phillip89@gmail.com : paymentMethods--> 1 transactions--> 3 orders--> 3
# ugood@mosley.info : paymentMethods--> 4 transactions--> 2 orders--> 2
# zgraham@yahoo.com : paymentMethods--> 3 transactions--> 5 orders--> 4
# pchavez@randolph.com : paymentMethods--> 1 transactions--> 1 orders--> 1
# marywalker@gmail.com : paymentMethods--> 3 transactions--> 4 orders--> 3
# shawseth@stout-novak.com : paymentMethods--> 1 transactions--> 0 orders--> 0
# smithtonya@huffman.org : paymentMethods--> 1 transactions--> 3 orders--> 3
# hamiltonchristopher@yahoo.com : paymentMethods--> 3 transactions--> 2 orders--> 1
# amywright@wallace-johnson.com : paymentMethods--> 1 transactions--> 6 orders--> 6
# iray@rogers.com : paymentMethods--> 5 transactions--> 5 orders--> 5
# ctaylor@yahoo.com : paymentMethods--> 6 transactions--> 8 orders--> 6
# kellyfrank@atkinson.com : paymentMethods--> 1 transactions--> 0 orders--> 0
# gomezjohn@yahoo.com : paymentMethods--> 1 transactions--> 2 orders--> 2
# mullenstephanie@yahoo.com : paymentMethods--> 2 transactions--> 3 orders--> 3
# wbeltran@ramirez-shaffer.com : paymentMethods--> 0 transactions--> 0 orders--> 0
# koneal@henderson.biz : paymentMethods--> 1 transactions--> 4 orders--> 4
# xramos@hardy.net : paymentMethods--> 1 transactions--> 0 orders--> 0
# brianthomas@yahoo.com : paymentMethods--> 1 transactions--> 6 orders--> 4
# oaguirre@hotmail.com : paymentMethods--> 4 transactions--> 1 orders--> 1
# joshua00@hotmail.com : paymentMethods--> 2 transactions--> 5 orders--> 4
# veronica42@stokes.com : paymentMethods--> 1 transactions--> 1 orders--> 1
# cindydeleon@yahoo.com : paymentMethods--> 2 transactions--> 4 orders--> 1
# johnlowery@gmail.com : paymentMethods--> 0 transactions--> 0 orders--> 0
# kyle64@stephens-ortiz.com : paymentMethods--> 1 transactions--> 5 orders--> 4
# jordanthomas@hayes-wilson.biz : paymentMethods--> 3 transactions--> 4 orders--> 4
# aliciaanthony@martin.com : paymentMethods--> 1 transactions--> 3 orders--> 3
# stephanie21@reyes-spencer.biz : paymentMethods--> 0 transactions--> 0 orders--> 0
# jenniferperry@hotmail.com : paymentMethods--> 2 transactions--> 4 orders--> 4
# bhorne@fuller-nelson.com : paymentMethods--> 0 transactions--> 0 orders--> 0
# lsanchez@hotmail.com : paymentMethods--> 2 transactions--> 5 orders--> 4
# christinemills@mcgee.com : paymentMethods--> 2 transactions--> 5 orders--> 5
# cuevasvicki@gmail.com : paymentMethods--> 3 transactions--> 6 orders--> 5
# mitchellgriffith@yahoo.com : paymentMethods--> 1 transactions--> 15 orders--> 3
# gwilcox@hotmail.com : paymentMethods--> 5 transactions--> 7 orders--> 6
# victorgarcia@gmail.com : paymentMethods--> 1 transactions--> 1 orders--> 1
# brittany60@yahoo.com : paymentMethods--> 2 transactions--> 5 orders--> 4
# fharris@hotmail.com : paymentMethods--> 1 transactions--> 4 orders--> 2
# mercedesfinley@roman.org : paymentMethods--> 4 transactions--> 5 orders--> 5
# davidwalker@hotmail.com : paymentMethods--> 0 transactions--> 0 orders--> 0
# philipnelson@dean.com : paymentMethods--> 0 transactions--> 0 orders--> 0
# 1yf0@jedyz63t : paymentMethods--> 4 transactions--> 10 orders--> 5
# thomasryan@conrad.net : paymentMethods--> 2 transactions--> 5 orders--> 3
# kwalsh@lopez-gomez.biz : paymentMethods--> 2 transactions--> 3 orders--> 3
# martinezlori@gmail.com : paymentMethods--> 1 transactions--> 5 orders--> 3
# johnlowery@gmail.com : paymentMethods--> 3 transactions--> 6 orders--> 5
# stevehernandez@gmail.com : paymentMethods--> 1 transactions--> 6 orders--> 5
# daniel98@lamb.com : paymentMethods--> 1 transactions--> 1 orders--> 1
# ujackson@harris.com : paymentMethods--> 2 transactions--> 5 orders--> 4
# brittanyhicks@jones.com : paymentMethods--> 1 transactions--> 2 orders--> 1
# deborah38@yahoo.com : paymentMethods--> 1 transactions--> 1 orders--> 1
# andre74@patrick-decker.com : paymentMethods--> 4 transactions--> 5 orders--> 4
# patrickcalderon@russo.net : paymentMethods--> 1 transactions--> 3 orders--> 2
# mitchellvickie@brewer-jones.com : paymentMethods--> 1 transactions--> 3 orders--> 3
# sbrown@hughes.biz : paymentMethods--> 3 transactions--> 6 orders--> 5
# johnlowery@gmail.com : paymentMethods--> 2 transactions--> 4 orders--> 4
# ethompson@jackson-sanders.com : paymentMethods--> 6 transactions--> 8 orders--> 6
# dawn05@tucker-brown.com : paymentMethods--> 4 transactions--> 7 orders--> 5

# %% [markdown]
# <b>By looking at the data. We have details about customer , mutiple payment methods, transaction and orders. A fraudulent node tells us whether the customer is fraudulent or not</b>

# %%
#Data point example
import json
data = []
with open('customersdata.json') as f:
    for line in f:
        data.append(json.loads(line))
print('--'*10,'Customer Details','--'*10)
for item in data[0]['customer'].items():
    print(item[0],'-->',item[1])
print('--'*10,'Payment Details','--'*10)
for j,item in enumerate(data[0]['paymentMethods']):
    print('Payment',j+1)
    print(item.values())
    for i in item.items():
        print(i[0],'-->',i[1])
print('--'*10,'transactions','--'*10)
for j,item in enumerate(data[0]['transactions']):
    print('Transaction',j+1)
    for i in item.items():
        print(i[0],'-->',i[1])
print('--'*10,'orders','--'*10)
for j,item in enumerate(data[0]['orders']):
    print('Order',j+1)
    for i in item.items():
        print(i[0],'-->',i[1])
print('--'*10,'Fradulent?','--'*10)
print('Yes' if data[0]['fraudulent'] else 'No')
    #print(item[0],'-->',item[1])
#print(data[0]['customer']['customerEmail'],': paymentMethods-->',len(data[0]['paymentMethods']),'transactions-->',(len(data[0]['transactions'])),'orders-->',len(data[0]['orders']))
# Out:
# -------------------- Customer Details --------------------
# customerEmail --> josephhoward@yahoo.com
# customerPhone --> 400-108-5415
# customerDevice --> yyeiaxpltf82440jnb3v
# customerIPAddress --> 8.129.104.40
# customerBillingAddress --> 5493 Jones Islands
# Brownside, CA 51896
# -------------------- Payment Details --------------------
# Payment 1
# dict_values(['wt07xm68b', True, 'card', 'JCB 16 digit', 'Citizens First Banks'])
# paymentMethodId --> wt07xm68b
# paymentMethodRegistrationFailure --> True
# paymentMethodType --> card
# paymentMethodProvider --> JCB 16 digit
# paymentMethodIssuer --> Citizens First Banks
# -------------------- transactions --------------------
# Transaction 1
# transactionId --> a9lcj51r
# orderId --> vjbdvd
# paymentMethodId --> wt07xm68b
# transactionAmount --> 18
# transactionFailed --> False
# Transaction 2
# transactionId --> y4wcv03i
# orderId --> yp6x27
# paymentMethodId --> wt07xm68b
# transactionAmount --> 26
# transactionFailed --> False
# -------------------- orders --------------------
# Order 1
# orderId --> vjbdvd
# orderAmount --> 18
# orderState --> pending
# orderShippingAddress --> 5493 Jones Islands
# Brownside, CA 51896
# Order 2
# orderId --> yp6x27
# orderAmount --> 26
# orderState --> fulfilled
# orderShippingAddress --> 5493 Jones Islands
# Brownside, CA 51896
# -------------------- Fradulent? --------------------
# No

# %% [markdown]
# <h2>Converting json data into Dataframes</h2>

# %%
def get_cust_transactions(customer_id,c_trn):
    cust_transactions=[]
    cust_transactions1=[]
    for item in c_trn:
        #print('Transaction',j+1)
        cust_transactions1.append(customer_id)
        cust_transactions1.extend(item.values())
        cust_transactions.append(cust_transactions1)
        cust_transactions1=[]
    return cust_transactions,len(c_trn)
def get_cust_orders(customer_id,c_orders):
    cust_orders=[]
    cust_orders1=[]
    for item in c_orders:
        #print('Transaction',j+1)
        cust_orders1.append(customer_id)
        cust_orders1.extend(item.values())
        cust_orders.append(cust_orders1)
        cust_orders1=[]
    return cust_orders,len(c_orders)
def get_cust_payment_methods(customer_id,c_payment_methods):
    cust_pmethods=[]
    cust_pmethods1=[]
    for item in c_payment_methods:
        #print('Transaction',j+1)
        cust_pmethods1.append(customer_id)
        cust_pmethods1.extend(item.values())
        cust_pmethods.append(cust_pmethods1)
        cust_pmethods1=[]
    return cust_pmethods,len(c_payment_methods)

# %%
data = []
with open('customersdata.json') as f:
    for line in f:
        data.append(json.loads(line))

# %%
import json
customer_details=[]
customer_payments=[]
customer_transactions=[]
customer_orders=[]
customer_details_bkp=[]
for p in data:
    customer_details_bkp.append(list(p['customer'].values()))
    t_temp = get_cust_transactions(p['customer']['customerEmail'],p['transactions'])
    o_temp = get_cust_orders(p['customer']['customerEmail'],p['orders'])
    p_temp  = get_cust_payment_methods(p['customer']['customerEmail'],p['paymentMethods'])
    customer_transactions.extend(t_temp[0])
    customer_orders.extend(o_temp[0])
    customer_payments.extend(p_temp[0])
    customer_details_bkp[0].extend([t_temp[1],o_temp[1],p_temp[1],p['fraudulent']])
    customer_details.append(customer_details_bkp[0])
    customer_details_bkp=[]

# %% [markdown]
# <h2>Creating Dataframes for the customer details, payments, transactions and orders</h2>

# %%
import pandas as pd
customer_columns=['customerEmail', 'customerPhone', 'customerDevice', 'customerIPAddress', 'customerBillingAddress','No_Transactions','No_Orders','No_Payments','Fraud']
order_columns=['customerEmail', 'orderId', 'orderAmount', 'orderState', 'orderShippingAddress']
payemnt_columns=['customerEmail', 'paymentMethodId', 'paymentMethodRegistrationFailure', 'paymentMethodType', 'paymentMethodProvider', 'paymentMethodIssuer']
transaction_columns=['customerEmail', 'transactionId', 'orderId', 'paymentMethodId', 'transactionAmount', 'transactionFailed']
Customer_DF = pd.DataFrame(customer_details,columns=customer_columns)
Customer_Orders_DF = pd.DataFrame(customer_orders,columns=order_columns)
Customer_Payment_DF = pd.DataFrame(customer_payments,columns=payemnt_columns)
Customer_transaction_DF = pd.DataFrame(customer_transactions,columns=transaction_columns)

# %%
Customer_DF.head()
# Out:
#                customerEmail       customerPhone        customerDevice  \
# 0     josephhoward@yahoo.com        400-108-5415  yyeiaxpltf82440jnb3v
# 1     evansjeffery@yahoo.com      1-788-091-7546  r0jpm7xaeqqa3kr6mzum
# 2  andersonwilliam@yahoo.com        024.420.0375  4m7h5ipl1shyavt6vv2r
# 3      rubenjuarez@yahoo.com  670.664.8168x94985  slovx60t0i558may4ks0
# 4           uchen@malone.com      1-981-877-0870  j0pd24k5h8dl2fqu0cz4
#
#                          customerIPAddress  \
# 0                             8.129.104.40
# 1                          219.173.211.202
# 2  67b7:3db8:67e0:3bea:b9d0:90c1:2b60:b9f0
# 3  95de:8565:5a66:792c:26e0:6cfb:7d87:11af
# 4                           196.89.235.192
#
#                               customerBillingAddress  No_Transactions  \
# 0            5493 Jones Islands\nBrownside, CA 51896                2
# 1  356 Elizabeth Inlet Suite 120\nPort Joshuabury...                3
# 2     8478 Sean Ridges Apt. 441\nDavisberg, PR 72250                5
# 3  7769 Elizabeth Bridge Apt. 343\nNortonstad, FM...                3
# 4  148 Russell Lodge Apt. 445\nPort Jenniferside,...                7
#
#    No_Orders  No_Payments  Fraud
# 0          2            1  False
# 1          3            7   True
# 2          3            2  False
# 3          3            1  False
# 4          7            6   True

# %%
Customer_Orders_DF.head()
# Out:
#             customerEmail orderId  orderAmount orderState  \
# 0  josephhoward@yahoo.com  vjbdvd           18    pending
# 1  josephhoward@yahoo.com  yp6x27           26  fulfilled
# 2  evansjeffery@yahoo.com  nlghpa           45  fulfilled
# 3  evansjeffery@yahoo.com  uw0eeb           23  fulfilled
# 4  evansjeffery@yahoo.com  bn44oh           43  fulfilled
#
#                                 orderShippingAddress
# 0            5493 Jones Islands\nBrownside, CA 51896
# 1            5493 Jones Islands\nBrownside, CA 51896
# 2      898 Henry Ports\nNew Keithview, CA 95893-2497
# 3  356 Elizabeth Inlet Suite 120\nPort Joshuabury...
# 4         5093 Bryan Forks\nJoshuaton, FM 01565-9801

# %%
Customer_Payment_DF.head()
# Out:
#             customerEmail paymentMethodId  paymentMethodRegistrationFailure  \
# 0  josephhoward@yahoo.com       wt07xm68b                              True
# 1  evansjeffery@yahoo.com       y3xp697jx                              True
# 2  evansjeffery@yahoo.com       6krszxc05                             False
# 3  evansjeffery@yahoo.com       5z1szj2he                             False
# 4  evansjeffery@yahoo.com       m52tx8e1s                             False
#
#   paymentMethodType        paymentMethodProvider     paymentMethodIssuer
# 0              card                 JCB 16 digit    Citizens First Banks
# 1           bitcoin                VISA 16 digit            Solace Banks
# 2              card                VISA 16 digit          Vertex Bancorp
# 3              card  Diners Club / Carte Blanche  His Majesty Bank Corp.
# 4              card                   Mastercard          Vertex Bancorp

# %%
print(Customer_DF.shape)
print(Customer_Payment_DF.shape)
print(Customer_Orders_DF.shape)
# Out:
# (168, 11)
# (342, 6)
# (478, 5)

# %%
Customer_transaction_DF.head()
# Out:
#             customerEmail transactionId orderId paymentMethodId  \
# 0  josephhoward@yahoo.com      a9lcj51r  vjbdvd       wt07xm68b
# 1  josephhoward@yahoo.com      y4wcv03i  yp6x27       wt07xm68b
# 2  evansjeffery@yahoo.com      5mi94sfw  nlghpa       41ug157xz
# 3  evansjeffery@yahoo.com      br8ba1nu  uw0eeb       41ug157xz
# 4  evansjeffery@yahoo.com      a33145ss  bn44oh       y3xp697jx
#
#    transactionAmount  transactionFailed
# 0                 18              False
# 1                 26              False
# 2                 45              False
# 3                 23              False
# 4                 43               True

# %% [markdown]
# <h2>Data Description and EDA</h2>

# %%
print('total customer records',Customer_DF.shape[0], 'total unique customer',len(Customer_DF.customerEmail.unique()))
# Out:
# total customer records 168 total unique customer 161

# %%
Customer_DF[Customer_DF['customerEmail'].duplicated()]
# Out:
#             customerEmail       customerPhone        customerDevice  \
# 40   johnlowery@gmail.com    737-377-9701x577  jz66ap43id2y35ivfqa5
# 45   johnlowery@gmail.com    +16(4)9016414340  cdx178qymd6vy77nm4x3
# 65   johnlowery@gmail.com         04712252182  311kdz4c1210iixltk2j
# 79   johnlowery@gmail.com  1-820-539-4726x993  2in0fh7lep289n8dcbdz
# 133  johnlowery@gmail.com      1-143-059-1833  tyijaify2hqadwslejyr
# 155  johnlowery@gmail.com  076-099-0630x72770  6qy6oa3nqutsyyxzc54c
# 165  johnlowery@gmail.com    635.676.0955x524  969zz9zdj8z4gns4sx5p
#
#                            customerIPAddress  \
# 40   6c21:ac1d:2089:68fa:abb7:8c00:525f:6588
# 45                            222.79.159.140
# 65    42b3:df19:86fe:abd9:dafe:f6c1:eb76:c72
# 79                            163.128.139.42
# 133   e4c:fb48:8ee2:9819:6ae8:8d3f:3b6a:a788
# 155  f259:657f:f329:2fca:c06c:8b57:d6ac:2380
# 165   f82c:811f:8a02:e2d6:79b:fcaa:42de:570b
#
#                                 customerBillingAddress  No_Transactions  \
# 40   08238 Kyle Squares Suite 893\nMillermouth, IN ...                0
# 45             77711 Pamela Ridge\nNew Kayla, IL 27182                3
# 65   11704 Andrew Villages Apt. 035\nJamesfurt, OR ...                7
# 79             814 Wagner Union\nAshleymouth, HI 35617                2
# 133  518 Wood Mews Apt. 970\nDillonstad, NE 43317-3945                0
# 155  687 Rogers Bridge Suite 780\nValdezburgh, IN 2...                6
# 165           548 Bryant Inlet\nVeronicaside, OK 00522                4
#
#      No_Orders  No_Payments  Fraud
# 40           0            1   True
# 45           2            1   True
# 65           5            1   True
# 79           2            1   True
# 133          0            0   True
# 155          5            3   True
# 165          4            2   True

# %% [markdown]
# There are 8 duplicate emails in the data, and all these records are classified as fraduluent.
# Created a column called is_duplicate to catch this behaviour

# %%
Customer_DF['Is_Duplicate_Name'] = Customer_DF['customerEmail'].apply(lambda x: 1 if (Customer_DF[Customer_DF.customerEmail==x]['customerEmail'].shape[0]>1) else 0)
Customer_DF['Is_Duplicate_IP'] = Customer_DF['customerIPAddress'].apply(lambda x: 1 if (Customer_DF[Customer_DF.customerIPAddress==x]['customerIPAddress'].shape[0]>1) else 0)
Customer_DF['Is_Duplicate_Address'] = Customer_DF['customerBillingAddress'].apply(lambda x: 1 if (Customer_DF[Customer_DF.customerBillingAddress==x]['customerBillingAddress'].shape[0]>1) else 0)

# %%
Customer_DF.head()
# Out:
#                customerEmail       customerPhone        customerDevice  \
# 0     josephhoward@yahoo.com        400-108-5415  yyeiaxpltf82440jnb3v
# 1     evansjeffery@yahoo.com      1-788-091-7546  r0jpm7xaeqqa3kr6mzum
# 2  andersonwilliam@yahoo.com        024.420.0375  4m7h5ipl1shyavt6vv2r
# 3      rubenjuarez@yahoo.com  670.664.8168x94985  slovx60t0i558may4ks0
# 4           uchen@malone.com      1-981-877-0870  j0pd24k5h8dl2fqu0cz4
#
#                          customerIPAddress  \
# 0                             8.129.104.40
# 1                          219.173.211.202
# 2  67b7:3db8:67e0:3bea:b9d0:90c1:2b60:b9f0
# 3  95de:8565:5a66:792c:26e0:6cfb:7d87:11af
# 4                           196.89.235.192
#
#                               customerBillingAddress  No_Transactions  \
# 0            5493 Jones Islands\nBrownside, CA 51896                2
# 1  356 Elizabeth Inlet Suite 120\nPort Joshuabury...                3
# 2     8478 Sean Ridges Apt. 441\nDavisberg, PR 72250                5
# 3  7769 Elizabeth Bridge Apt. 343\nNortonstad, FM...                3
# 4  148 Russell Lodge Apt. 445\nPort Jenniferside,...                7
#
#    No_Orders  No_Payments  Fraud  Fraud_Decoded  Is_Duplicate_Name  \
# 0          2            1  False              0                  0
# 1          3            7   True              1                  0
# 2          3            2  False              0                  0
# 3          3            1  False              0                  0
# 4          7            6   True              1                  0
#
#    No_Successfull_Transactions  No_Failed_Transactions  No_Failed_Orders  \
# 0                            2                       0                 0
# 1                            2                       1                 0
# 2                            3                       2                 1
# 3                            3                       0                 0
# 4                            5                       2                 1
#
#    No_Success_Orders  No_Pending_Orders  Is_Duplicate_IP  Is_Duplicate_Address
# 0                  1                  1                0                     0
# 1                  3                  0                0                     0
# 2                  2                  0                0                     0
# 3                  3                  0                0                     0
# 4                  6                  0                0                     0

# %% [markdown]
# <h2>Customer with maximum orders , transactions and payments</h2>

# %%
Customer_DF[Customer_DF.No_Transactions==Customer_DF.No_Transactions.max()]
# Out:
#                   customerEmail        customerPhone        customerDevice  \
# 143  mitchellgriffith@yahoo.com  1-321-386-6855x0101  72stamnugxuz9ls1xx98
#
#     customerIPAddress            customerBillingAddress  No_Transactions  \
# 143    158.185.147.61  Unit 6719 Box 6044\nDPO AE 33534               15
#
#      No_Orders  No_Payments  Fraud  Fraud_Decoded
# 143          3            1  False              0

# %%
Customer_DF[Customer_DF.No_Orders==Customer_DF.No_Orders.max()]
# Out:
#                    customerEmail         customerPhone        customerDevice  \
# 84   lleonard@turner-fleming.com  1-414-937-7421x73705  yfpqgg5oxsn107veaala
# 97           vmiller@hotmail.com          000-734-4774  b1tjk5s0j9ybj1qpt3ik
# 98             david45@gmail.com         (508)223-3834  l6qv05oe0h0j78kx84ex
# 103        tmcpherson@wright.com  1-804-264-1481x08539  ui77ukzr5lnqpajdk03u
#
#                            customerIPAddress  \
# 84                              97.111.97.42
# 97                              164.79.214.9
# 98   9d8d:535b:36fc:8773:bec0:8fa5:3206:4cb5
# 103  296d:59fe:a919:21ac:16dd:96f5:10b3:4f83
#
#                                 customerBillingAddress  No_Transactions  \
# 84      96103 Riley Walks\nMichellefort, ID 98085-6066               11
# 97               PSC 9111, Box 9839\nAPO AA 57283-9646               10
# 98   5360 Adams Falls Suite 829\nHensleymouth, WV 8...               10
# 103  7956 Alex Avenue Apt. 593\nPort Michael, OK 41350               13
#
#      No_Orders  No_Payments  Fraud
# 84           8            1   True
# 97           8            1   True
# 98           8            5   True
# 103          8            1   True

# %%
Customer_DF[Customer_DF.No_Payments==Customer_DF.No_Payments.max()]
# Out:
#          customerEmail       customerPhone        customerDevice  \
# 68  cathy42@gibson.com  754.248.6239x43965  c3r2qzqwc9anp6utob7n
#
#                           customerIPAddress  \
# 68  7493:ab04:47ff:3a14:67d6:a128:a5b6:1500
#
#                                customerBillingAddress  No_Transactions  \
# 68  046 Carson Crescent\nSouth Jacksonview, NV 228...                3
#
#     No_Orders  No_Payments  Fraud  Fraud_Decoded
# 68          3           15   True              1

# %%
Customer_DF['Fraud_Decoded'] = Customer_DF['Fraud'].apply(lambda x: 1 if x else 0)

# %%
print('Average No payments ',round(Customer_DF.No_Payments.mean()))
print('Average No Transactions ',round(Customer_DF.No_Transactions.mean()))
print('Average No orders ',round(Customer_DF.No_Orders.mean() ))
# Out:
# Average No payments  2
# Average No Transactions  4
# Average No orders  3

# %%
import matplotlib.pyplot as plt
Customer_DF.groupby(by=['Fraud'])['Fraud'].count().plot(kind='bar')
plt.title('Class counts')
plt.show()

# %% [markdown]
# <b>Classes are partially balanced</b>

# %%
import pandas as pd
import seaborn as sns
sns.set(style="whitegrid", palette="muted")

# "Melt" the dataset to "long-form" or "tidy" representation
abc = pd.melt(Customer_DF[['No_Transactions','No_Orders','No_Payments','Fraud']], "Fraud", var_name="features")

# Draw a categorical scatterplot to show each observation
plt.figure(figsize=(10, 6))
sns.swarmplot(x="features", y="value", hue="Fraud",
              palette=["r", "c", "y"], data=abc)

# %% [markdown]
# <b> As we see that, if the values of any feature is higher then we can say that,it is non fraudulent transaction.
# But we are not sure about the fraudulent transactions.We need to do some feature engineering techniques to seggregate the model properly</b>

# %%
X = Customer_DF[['No_Transactions','No_Orders','No_Payments']].values
y = Customer_DF.Fraud_Decoded.values

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=0)
X_2d = tsne.fit_transform(X)

# %%
target_ids = range(2)

from matplotlib import pyplot as plt
plt.figure(figsize=(6, 5))
colors = 'r', 'g'
for i, c, label in zip(target_ids, colors, ['True','False']):
    plt.scatter(X_2d[y == i, 0], X_2d[y == i, 1], c=c, label=label)
plt.legend()
plt.show()

# %% [markdown]
# <b>With TSNE also, we cannot able to seggregate the data </b>

# %%
import sqlite3
conn = sqlite3.connect('task1.sqlite')
Customer_Orders_DF.to_sql('Customer_Orders_DF', conn, if_exists='replace', index=False)
Customer_Payment_DF.to_sql('Customer_Payment_DF', conn, if_exists='replace', index=False)
Customer_transaction_DF.to_sql('Customer_transaction_DF', conn, if_exists='replace', index=False)
#print(pd.read_sql('select * from Customer_Orders_DF', conn))
conn.close()

# %%
conn = sqlite3.connect('task1.sqlite')

# %%
cust_transaction_details  = pd.read_sql('select b.customerEmail,b.transactionId,b.orderId,b.paymentMethodId,'+
            '(select paymentMethodRegistrationFailure from Customer_Payment_DF d where d.customerEmail=b.customerEmail and d.paymentMethodId=b.paymentMethodId) as paymentMethodRegistrationFailure,'+
            '(select paymentMethodType from Customer_Payment_DF d where d.customerEmail=b.customerEmail and d.paymentMethodId=b.paymentMethodId) as paymentMethodType,'+
            '(select paymentMethodProvider from Customer_Payment_DF d where d.customerEmail=b.customerEmail and d.paymentMethodId=b.paymentMethodId) as paymentMethodProvider,'+
            'b.transactionAmount,b.transactionFailed,a.orderState '+
            'from Customer_Orders_DF a, Customer_transaction_DF b where a.customerEmail=b.customerEmail and ' +
           ' a.orderId=b.orderId', conn)

# %%
cust_transaction_details.to_csv('cust_transaction_details.csv')

# %%
cust_transaction_details.customerEmail.unique().shape
# Out:
# (136,)

# %% [markdown]
# out of 161 customers , 136 made atleast one transaction and has payments done.

# %%
#Lets See if a customer has not opted for any payment method, whether he is fraud or not?
Customer_DF[Customer_DF.No_Payments==0]
# Out:
#                      customerEmail         customerPhone  \
# 34            zbennett@frazier.com      995.449.5115x498
# 38                 xwang@white.com      592.309.4963x427
# 44                gsimpson@cox.org      +23(4)1428642270
# 47       johnsonjennifer@yahoo.com  1-670-969-5075x27186
# 54               zthomas@gmail.com    731.957.1783x62296
# 70        brockmatthew@hotmail.com      800.814.4655x012
# 125   wbeltran@ramirez-shaffer.com   1-627-545-5097x7356
# 133           johnlowery@gmail.com        1-143-059-1833
# 137  stephanie21@reyes-spencer.biz     990.862.5466x7247
# 139       bhorne@fuller-nelson.com        1-512-954-5541
# 149        davidwalker@hotmail.com           02877590244
# 150          philipnelson@dean.com          534-301-8809
#
#            customerDevice                        customerIPAddress  \
# 34   zxdd5co6f5pylq9it4x0  e03d:db6e:f5ca:b9cd:d64f:80fe:6177:26e1
# 38   1qj6z7funp3l28ym8trh  7891:9f08:9ac6:c816:7c58:26cd:ff2c:7ddc
# 44   nf0i429dh2h2fmf287ec                               20.34.8.37
# 47   yqt388sj7f142rohzukc                            172.191.99.44
# 54   7p70n6q6zbgfhiqqqsxy  ad37:7b02:70fb:4b74:bc77:cd13:1bed:2483
# 70   132m3ourosp5a28ksvou                           188.74.171.130
# 125  z0uxvp8sio7nyv7op58j    1b75:d451:c48a:12:cfc7:bc1e:d748:ee62
# 133  tyijaify2hqadwslejyr   e4c:fb48:8ee2:9819:6ae8:8d3f:3b6a:a788
# 137  r526953keh7ctxcf9lnh   96eb:8d53:678:53ba:599b:5db6:3fe3:3218
# 139  dgfa5pe2t45d1u6ox33l  118e:7887:94b6:b2a7:d2ad:8f35:c241:3149
# 149  96ikyqg56kakwa4eix4q  e634:6f95:c48d:8db4:8e95:dfc8:7225:1e0a
# 150  xvxnwq1qs3gglt4k4g5t    ea1d:c7d:1e39:a10d:d15f:6430:d2a6:aaf
#
#                                 customerBillingAddress  No_Transactions  \
# 34   89773 Peterson Course Suite 625\nEast Amandabo...                0
# 38    139 Ramirez Island Suite 885\nNew Joan, MT 69993                0
# 44     32514 Freeman Court\nPort Waltermouth, SC 34012                0
# 47   6395 Christopher Lakes Suite 062\nSouth Dana, ...                0
# 54   01494 Anderson Corners Suite 314\nDaviston, SC...                0
# 70   08645 Alvarado Way Suite 514\nMillerfurt, AL 8...                0
# 125  4873 Perez Groves\nWest Gregoryburgh, NH 45193...                0
# 133  518 Wood Mews Apt. 970\nDillonstad, NE 43317-3945                0
# 137  31068 Vance Forks Suite 516\nNew Christopher, ...                0
# 139           25653 Key Gateway\nPort Robert, PA 64370                0
# 149  8765 Dyer Alley Apt. 682\nDominguezburgh, ME 7...                0
# 150     40185 Kim Motorway\nShawchester, IL 78234-1556                0
#
#      No_Orders  No_Payments  Fraud  Fraud_Decoded  Is_Duplicate_Name
# 34           0            0  False              0                  0
# 38           0            0  False              0                  0
# 44           0            0  False              0                  0
# 47           0            0  False              0                  0
# 54           0            0  False              0                  0
# 70           0            0  False              0                  0
# 125          0            0  False              0                  0
# 133          0            0   True              1                  1
# 137          0            0  False              0                  0
# 139          0            0  False              0                  0
# 149          0            0  False              0                  0
# 150          0            0  False              0                  0

# %% [markdown]
# <b>If the no of payment methods mentioned are 0 and no duplicates ,then he is not a fraud</b>

# %%
Customer_Payment_DF.paymentMethodType.unique()
# Out:
# array(['card', 'bitcoin', 'apple pay', 'paypal'], dtype=object)

# %% [markdown]
# <h2>Lets look at how many successfull transactions did by a cutomer till now</h2>

# %%
cust_transaction_details[(cust_transaction_details.transactionFailed>0) & (cust_transaction_details.customerEmail=='vmiller@hotmail.com')].groupby(['customerEmail'])['transactionFailed'].count()
# Out:
# customerEmail
# vmiller@hotmail.com    3
# Name: transactionFailed, dtype: int64

# %%
Customer_DF['No_Successfull_Transactions'] = Customer_DF['customerEmail'].apply(lambda x: cust_transaction_details[(cust_transaction_details.transactionFailed==0) & (cust_transaction_details.customerEmail==x)]['transactionFailed'].count())
Customer_DF['No_Failed_Transactions'] = Customer_DF['customerEmail'].apply(lambda x: cust_transaction_details[(cust_transaction_details.transactionFailed>0) & (cust_transaction_details.customerEmail==x)]['transactionFailed'].count())
Customer_DF['No_Transactions']=Customer_DF['customerEmail'].apply(lambda x: cust_transaction_details[ (cust_transaction_details.customerEmail==x)]['transactionId'].count())
Customer_DF['No_Orders']=Customer_DF['customerEmail'].apply(lambda x: Customer_Orders_DF[ (Customer_Orders_DF.customerEmail==x)]['orderId'].count())
Customer_DF['No_Payments']=Customer_DF['customerEmail'].apply(lambda x: Customer_Payment_DF[(Customer_Payment_DF.customerEmail==x)]['paymentMethodId'].count())

# %%
cust_transaction_details[(cust_transaction_details.orderState=='fulfilled') ].sort_values(by=['customerEmail'])
# Out:
#                       customerEmail transactionId orderId paymentMethodId  \
# 552                   1yf0@jedyz63t      pkc9dfn2  st9dv0       0l7kszls7
# 551                   1yf0@jedyz63t      i4edjdey  st9dv0       0l7kszls7
# 550                   1yf0@jedyz63t      cnion0pc  st9dv0       0l7kszls7
# 543                   1yf0@jedyz63t      foo56851  gcop7b       igpmsjd73
# 544                   1yf0@jedyz63t      drngwa51  eftfwy       0l7kszls7
# 545                   1yf0@jedyz63t      5010w1m2  1ca3sy       vej6hz0vq
# 546                   1yf0@jedyz63t      xyavqxjg  1ca3sy       0l7kszls7
# 547                   1yf0@jedyz63t      84xwwv0d  is64fx       igpmsjd73
# 549                   1yf0@jedyz63t      7nib2tyk  st9dv0       0l7kszls7
# 548                   1yf0@jedyz63t      67o717jo  st9dv0       igpmsjd73
# 130                     9es7t@u6n7x      yz35aas7  3b9vdf       wl0wgtfn2
# 129                     9es7t@u6n7x      7m39em4p  3b9vdf       wl0wgtfn2
# 115             abigail08@yahoo.com      97sqcd6l  l98c04       tfcg9eqwk
# 73                  alec27@bell.com      u6wa5ysx  j7ene4       6n2psn50k
# 74                  alec27@bell.com      vfrua0id  j7ene4       366dsl3w0
# 75                  alec27@bell.com      jh5r2s3s  mir5zf       366dsl3w0
# 71                  alec27@bell.com      60kuyxra  iyl91j       6n2psn50k
# 72                  alec27@bell.com      gj13pt1o  j7ene4       6n2psn50k
# 483        aliciaanthony@martin.com      d27dmlyt  dzj9zm       5tyvyueom
# 485        aliciaanthony@martin.com      jxosraoj  ijyrzl       5tyvyueom
# 484        aliciaanthony@martin.com      m5ojvu3i  od1sqr       5tyvyueom
# 431   amywright@wallace-johnson.com      ewy4l0pq  6hb7do       88huac0bv
# 434   amywright@wallace-johnson.com      1vw81h7t  t8lnr5       88huac0bv
# 433   amywright@wallace-johnson.com      aus7niea  y942bm       88huac0bv
# 9         andersonwilliam@yahoo.com      uo3slwh7  itnk8y       8pneoi03z
# 8         andersonwilliam@yahoo.com      pegqc4ud  itnk8y       dluy3jka0
# 7         andersonwilliam@yahoo.com      69w9wymx  28v6b0       8pneoi03z
# 6         andersonwilliam@yahoo.com      3alf9irw  28v6b0       8pneoi03z
# 591      andre74@patrick-decker.com      0rtt6tgw  aj4xtw       ru0jjkjlt
# 588      andre74@patrick-decker.com      8f8tkglk  yjyogo       ru0jjkjlt
# ..                              ...           ...     ...             ...
# 351             vmiller@hotmail.com      1fvxj1f7  kclajf       syeg4jsea
# 352             vmiller@hotmail.com      2pxfi412  src36a       syeg4jsea
# 353             vmiller@hotmail.com      vmzjq1hz  src36a       syeg4jsea
# 349             vmiller@hotmail.com      1hnqqte8  1r723d       syeg4jsea
# 402                vreyes@cruz.info      7pupat69  b1t6wl       gw4lq4cuy
# 288         warrenedward@arnold.com      kaxr9ib2  mfgt1j       v50sqfm8h
# 287         warrenedward@arnold.com      409r48ot  v3f3bo       bhta4vgb5
# 286         warrenedward@arnold.com      1od1zuej  e32v3f       3ahrb9ife
# 285         warrenedward@arnold.com      0w4ng8t4  03euof       v50sqfm8h
# 332  watkinscaroline@lewis-haas.com      qv0juj5h  kcyceh       zsk2itfp9
# 331  watkinscaroline@lewis-haas.com      evap24h5  z4z8pu       zsk2itfp9
# 392             wdelacruz@yahoo.com      z7wlutjb  lqc3os       n8g5z0l5a
# 395             wdelacruz@yahoo.com      m4c0aa62  j6lfpo       n8g5z0l5a
# 307      whitedavid@jones-lloyd.org      3pymh6mw  gdsjvg       twmq62jy6
# 308      whitedavid@jones-lloyd.org      unkt953p  3oa84g       schhirx31
# 311      whitedavid@jones-lloyd.org      i8ish28k  0ssrq7       twmq62jy6
# 309      whitedavid@jones-lloyd.org      009jh4iq  a8rmch       twmq62jy6
# 401                ybrown@gmail.com      jauf6x87  1x9wie       os6ezvnwg
# 400                ybrown@gmail.com      2obfozx3  1x9wie       os6ezvnwg
# 398                ybrown@gmail.com      zzg2ywpl  w936ae       4wf6hh0n2
# 397                ybrown@gmail.com      syutt7yx  cdt22w       vnrb9adla
# 133             ypruitt@hotmail.com      bzubcvnz  5pwn81       vwdxqd00s
# 134             ypruitt@hotmail.com      qyw32m2v  l72b2v       vwdxqd00s
# 131             ypruitt@hotmail.com      h7huu8lz  wc0qut       vwdxqd00s
# 132             ypruitt@hotmail.com      t55qhcm8  8o9ef7       vwdxqd00s
# 417               zgraham@yahoo.com      93wgj32w  3g1bbj       ougmgyvof
# 416               zgraham@yahoo.com      cosa5rtj  9khtcz       ougmgyvof
# 415               zgraham@yahoo.com      82m0gkqr  0linjx       4lbflweug
# 414               zgraham@yahoo.com      tyhoucmk  4pg8fk       l4w49qskr
# 418               zgraham@yahoo.com      trxn5ehm  3g1bbj       4lbflweug
#
#      paymentMethodRegistrationFailure paymentMethodType paymentMethodProvider  \
# 552                                 0              card         VISA 13 digit
# 551                                 0              card         VISA 13 digit
# 550                                 0              card         VISA 13 digit
# 543                                 0            paypal            Mastercard
# 544                                 0              card         VISA 13 digit
# 545                                 0              card               Maestro
# 546                                 0              card         VISA 13 digit
# 547                                 0            paypal            Mastercard
# 549                                 0              card         VISA 13 digit
# 548                                 0            paypal            Mastercard
# 130                                 0              card               Voyager
# 129                                 0              card               Voyager
# 115                                 1              card               Maestro
# 73                                  0              card               Voyager
# 74                                  0              card         VISA 16 digit
# 75                                  0              card         VISA 16 digit
# 71                                  0              card               Voyager
# 72                                  0              card               Voyager
# 483                                 0              card               Maestro
# 485                                 0              card               Maestro
# 484                                 0              card               Maestro
# 431                                 1           bitcoin         VISA 16 digit
# 434                                 1           bitcoin         VISA 16 digit
# 433                                 1           bitcoin         VISA 16 digit
# 9                                   0              card          JCB 16 digit
# 8                                   0              card              Discover
# 7                                   0              card          JCB 16 digit
# 6                                   0              card          JCB 16 digit
# 591                                 0              card          JCB 16 digit
# 588                                 0              card          JCB 16 digit
# ..                                ...               ...                   ...
# 351                                 0              card          JCB 16 digit
# 352                                 0              card          JCB 16 digit
# 353                                 0              card          JCB 16 digit
# 349                                 0              card          JCB 16 digit
# 402                                 0              card         VISA 13 digit
# 288                                 1              card      American Express
# 287                                 0         apple pay         VISA 13 digit
# 286                                 0              card               Voyager
# 285                                 1              card      American Express
# 332                                 0              card               Maestro
# 331                                 0              card               Maestro
# 392                                 0              card          JCB 16 digit
# 395                                 0              card          JCB 16 digit
# 307                                 1              card          JCB 16 digit
# 308                                 0              card          JCB 16 digit
# 311                                 1              card          JCB 16 digit
# 309                                 1              card          JCB 16 digit
# 401                                 0              card          JCB 16 digit
# 400                                 0              card          JCB 16 digit
# 398                                 0              card         VISA 16 digit
# 397                                 0              card               Voyager
# 133                                 0              card          JCB 15 digit
# 134                                 0              card          JCB 15 digit
# 131                                 0              card          JCB 15 digit
# 132                                 0              card          JCB 15 digit
# 417                                 0              card               Maestro
# 416                                 0              card               Maestro
# 415                                 0              card              Discover
# 414                                 0         apple pay               Voyager
# 418                                 0              card              Discover
#
#      transactionAmount  transactionFailed orderState
# 552                 12                  1  fulfilled
# 551                 12                  1  fulfilled
# 550                 12                  1  fulfilled
# 543                 38                  0  fulfilled
# 544                 11                  0  fulfilled
# 545                 45                  1  fulfilled
# 546                 45                  0  fulfilled
# 547                 18                  0  fulfilled
# 549                 12                  0  fulfilled
# 548                 12                  1  fulfilled
# 130                 16                  0  fulfilled
# 129                 16                  1  fulfilled
# 115                 29                  0  fulfilled
# 73                  30                  1  fulfilled
# 74                  30                  1  fulfilled
# 75                  22                  0  fulfilled
# 71                  12                  0  fulfilled
# 72                  30                  0  fulfilled
# 483                 45                  0  fulfilled
# 485                 11                  0  fulfilled
# 484                 39                  0  fulfilled
# 431                 71                  1  fulfilled
# 434                 44                  0  fulfilled
# 433                 32                  0  fulfilled
# 9                   25                  0  fulfilled
# 8                   25                  1  fulfilled
# 7                   24                  0  fulfilled
# 6                   24                  1  fulfilled
# 591                 36                  0  fulfilled
# 588                 26                  0  fulfilled
# ..                 ...                ...        ...
# 351                 54                  0  fulfilled
# 352                 55                  0  fulfilled
# 353                 55                  1  fulfilled
# 349                 64                  0  fulfilled
# 402                 30                  0  fulfilled
# 288                 11                  0  fulfilled
# 287                 28                  0  fulfilled
# 286                 31                  0  fulfilled
# 285                 47                  0  fulfilled
# 332                 27                  0  fulfilled
# 331                 11                  0  fulfilled
# 392                 66                  1  fulfilled
# 395                 72                  0  fulfilled
# 307                 70                  0  fulfilled
# 308                 52                  0  fulfilled
# 311                 45                  0  fulfilled
# 309                 73                  0  fulfilled
# 401                 10                  0  fulfilled
# 400                 10                  1  fulfilled
# 398                 42                  0  fulfilled
# 397                 46                  0  fulfilled
# 133                 49                  0  fulfilled
# 134                 29                  0  fulfilled
# 131                 30                  0  fulfilled
# 132                 38                  0  fulfilled
# 417                 11                  1  fulfilled
# 416                 12                  0  fulfilled
# 415                 43                  1  fulfilled
# 414                 42                  0  fulfilled
# 418                 11                  0  fulfilled
#
# [516 rows x 10 columns]

# %%
import re
def ret_trn_fail_ord_success(x):
    cust_dict={}
    for det in cust_transaction_details[(cust_transaction_details.customerEmail==x) & (cust_transaction_details.orderState=='fulfilled') & (cust_transaction_details.transactionFailed==1)].iterrows():
        #print(det[1].orderId)
        if not cust_transaction_details[(cust_transaction_details.customerEmail==det[1].customerEmail) & (cust_transaction_details.orderId==det[1].orderId) &
                                 (cust_transaction_details.transactionFailed==0)]['customerEmail'].count()>0:
            #print(det[1].orderId)
            cust_dict[det[1].orderId]=1
    return len(cust_dict)
def valid_email(email):
    if bool(re.search(r"^[\w\.\+\-]+\@[\w\-]+\.[a-z]{2,4}$", email)):
        return 1
    else:
        return 0
def ret_pay_counts(x):
    import pandas as pd
    lst1=[]
    for i in ['card', 'bitcoin', 'apple pay', 'paypal']:
        lst1.append(Customer_Payment_DF[(Customer_Payment_DF.customerEmail==x) &(Customer_Payment_DF.paymentMethodType==i) & (Customer_Payment_DF.paymentMethodRegistrationFailure==False)].shape[0])
    return pd.Series(lst1)

# %% [markdown]
# <h2>Pending, Failed, fulfilled orders per customer</h2>

# %%
Customer_DF[Customer_DF.customerEmail.isin(cust_transaction_details[cust_transaction_details.paymentMethodType=='bitcoin'].customerEmail.unique().tolist())]
# Out:
#                       customerEmail         customerPhone  \
# 1            evansjeffery@yahoo.com        1-788-091-7546
# 7              johnlowery@gmail.com          044-642-9860
# 11             ksummers@hotmail.com        1-023-275-4692
# 12   christineklein@wright-boyd.org      897-464-6425x941
# 16                 dana09@yahoo.com      515.708.2280x105
# 22            davismike@hotmail.com      467-222-0933x910
# 29            catherine64@gmail.com      563-396-2038x288
# 40             johnlowery@gmail.com      737-377-9701x577
# 45             johnlowery@gmail.com      +16(4)9016414340
# 64              suzanne21@gmail.com        1-043-962-2576
# 65             johnlowery@gmail.com           04712252182
# 66      kristaavery@lewis-baird.com    242.165.5396x07020
# 69         michelleherrera@day.info    1-991-286-0655x973
# 77                 udavis@clark.com         (942)067-2430
# 79             johnlowery@gmail.com    1-820-539-4726x993
# 87             tayloreric@gmail.com  1-160-137-7889x74832
# 93   craig83@rasmussen-alvarado.com      122-259-7479x336
# 98                david45@gmail.com         (508)223-3834
# 119   amywright@wallace-johnson.com          629.489.3980
# 124       mullenstephanie@yahoo.com     (616)674-0266x776
# 126            koneal@henderson.biz     059.431.5467x7848
# 133            johnlowery@gmail.com        1-143-059-1833
# 146            brittany60@yahoo.com         (172)959-5151
# 155            johnlowery@gmail.com    076-099-0630x72770
# 165            johnlowery@gmail.com      635.676.0955x524
# 166   ethompson@jackson-sanders.com          962.300.2250
#
#            customerDevice                        customerIPAddress  \
# 1    r0jpm7xaeqqa3kr6mzum                          219.173.211.202
# 7    rjb0adai34izqvys4938                           212.144.68.190
# 11   2ngkzu1idwxintmxwmgn                             184.97.57.11
# 12   j8cp1uydkuyza2eo0mir    4304:521a:e1c3:766b:21f3:ac3:4ab2:5a2
# 16   wb0uylp0rwy01x5j1jzd                           166.148.66.158
# 22   4hzaaor6es3iyuiavyio                            162.48.39.230
# 29   myjxxvd3jfn1eymfy50n   1289:d2a9:c65d:8fc7:7be4:129b:d7b:cf7b
# 40   jz66ap43id2y35ivfqa5  6c21:ac1d:2089:68fa:abb7:8c00:525f:6588
# 45   cdx178qymd6vy77nm4x3                           222.79.159.140
# 64   ewc3gyloi1ing9o64jpt   4834:7ccb:15de:9123:5658:42c3:cc50:79f
# 65   311kdz4c1210iixltk2j   42b3:df19:86fe:abd9:dafe:f6c1:eb76:c72
# 66   3wqhnieu6nbcis8x7h3j                            180.223.72.88
# 69   s7m2fjcrk1y7lj0amm08  fb35:e7e4:1368:817f:b75e:6473:d60b:93a8
# 77   y7b7eqwqn34mytvn1i5z                           146.191.70.148
# 79   2in0fh7lep289n8dcbdz                           163.128.139.42
# 87   sjoj10iss04dq90i4w7x                              3.75.86.140
# 93   s93o0wj3eqd9whcy9ng3                           35.212.254.226
# 98   l6qv05oe0h0j78kx84ex  9d8d:535b:36fc:8773:bec0:8fa5:3206:4cb5
# 119  n29he2b6a841zcbiw2i9                           254.155.117.48
# 124  056bfyj4m7svmdeex8z1                            50.190.231.22
# 126  gcfo5uheb9mugbstbjez                           85.188.105.126
# 133  tyijaify2hqadwslejyr   e4c:fb48:8ee2:9819:6ae8:8d3f:3b6a:a788
# 146  55uutypnlt0dve5gnzpx                           174.86.116.243
# 155  6qy6oa3nqutsyyxzc54c  f259:657f:f329:2fca:c06c:8b57:d6ac:2380
# 165  969zz9zdj8z4gns4sx5p   f82c:811f:8a02:e2d6:79b:fcaa:42de:570b
# 166  navessqcnmc9csfjn5cj                          203.246.172.244
#
#                                 customerBillingAddress  No_Transactions  \
# 1    356 Elizabeth Inlet Suite 120\nPort Joshuabury...                3
# 7     484 Pamela Pass\nLake Jessicaview, WI 12942-9074                6
# 11   46383 Matthew Track Apt. 220\nRomanburgh, DC 9...                7
# 12   67636 Renee Islands Suite 307\nTeresaview, ND ...                4
# 16   812 Moss Radial Suite 844\nNorth Patriciaburgh...                6
# 22   07078 Brent Ways Apt. 999\nAlvarezshire, ND 82309                4
# 29   372 Michael Club Suite 553\nHerrerafort, MH 52953                5
# 40   08238 Kyle Squares Suite 893\nMillermouth, IN ...                0
# 45             77711 Pamela Ridge\nNew Kayla, IL 27182                3
# 64        398 Latasha Canyon\nKathyland, LA 36717-2161                5
# 65   11704 Andrew Villages Apt. 035\nJamesfurt, OR ...                7
# 66     73802 Aaron Field Apt. 622\nPort Lisa, MO 01167                1
# 69    586 Johnson Courts\nSouth Timothymouth, OH 66490                6
# 77       9923 Williams Ramp\nEast Lauraburgh, GA 48874                3
# 79             814 Wagner Union\nAshleymouth, HI 35617                2
# 87   3195 Farmer Mills Apt. 946\nBrittanymouth, IA ...                4
# 93   10068 Adam Rapids Suite 792\nRileyburgh, GA 11372                2
# 98   5360 Adams Falls Suite 829\nHensleymouth, WV 8...               10
# 119     403 Anna Center Apt. 947\nMeganhaven, GA 46627                6
# 124  3483 Frank Estate Apt. 466\nThomasburgh, MP 54...                3
# 126  056 Megan Trail Suite 355\nWest Zachary, GU 51...                4
# 133  518 Wood Mews Apt. 970\nDillonstad, NE 43317-3945                0
# 146  603 Sophia Flat Suite 158\nSouth Wandaland, PR...                5
# 155  687 Rogers Bridge Suite 780\nValdezburgh, IN 2...                6
# 165           548 Bryant Inlet\nVeronicaside, OK 00522                4
# 166   16953 Jennifer Springs\nKathybury, IL 02095-3215                8
#
#      No_Orders  No_Payments  Fraud  Fraud_Decoded  Is_Duplicate_Name  \
# 1            3            7   True              1                  0
# 7            5            2   True              1                  1
# 11           5            4  False              0                  0
# 12           4            3  False              0                  0
# 16           3            2  False              0                  0
# 22           3            1  False              0                  0
# 29           4            6   True              1                  0
# 40           0            1   True              1                  1
# 45           2            1   True              1                  1
# 64           3            2   True              1                  0
# 65           5            1   True              1                  1
# 66           1            3  False              0                  0
# 69           4            1  False              0                  0
# 77           3            1  False              0                  0
# 79           2            1   True              1                  1
# 87           3            2  False              0                  0
# 93           2           13   True              1                  0
# 98           8            5   True              1                  0
# 119          6            1   True              1                  0
# 124          3            2  False              0                  0
# 126          4            1   True              1                  0
# 133          0            0   True              1                  1
# 146          4            2  False              0                  0
# 155          5            3   True              1                  1
# 165          4            2   True              1                  1
# 166          6            6   True              1                  0
#
#      No_Successfull_Transactions  No_Failed_Transactions  No_Failed_Orders  \
# 1                              2                       1                 0
# 7                             22                       6                 2
# 11                             4                       3                 0
# 12                             4                       0                 0
# 16                             3                       3                 0
# 22                             3                       1                 1
# 29                             4                       1                 1
# 40                            22                       6                 2
# 45                            22                       6                 2
# 64                             3                       2                 1
# 65                            22                       6                 2
# 66                             0                       1                 0
# 69                             4                       2                 1
# 77                             3                       0                 0
# 79                            22                       6                 2
# 87                             3                       1                 1
# 93                             1                       1                 0
# 98                             7                       3                 0
# 119                            5                       1                 3
# 124                            3                       0                 0
# 126                            4                       0                 0
# 133                           22                       6                 2
# 146                            4                       1                 1
# 155                           22                       6                 2
# 165                           22                       6                 2
# 166                            6                       2                 1
#
#      No_Success_Orders  No_Pending_Orders
# 1                    3                  0
# 7                   21                  0
# 11                   5                  0
# 12                   3                  1
# 16                   3                  0
# 22                   2                  0
# 29                   2                  1
# 40                  21                  0
# 45                  21                  0
# 64                   2                  0
# 65                  21                  0
# 66                   1                  0
# 69                   3                  0
# 77                   3                  0
# 79                  21                  0
# 87                   2                  0
# 93                   2                  0
# 98                   8                  0
# 119                  3                  0
# 124                  3                  0
# 126                  4                  0
# 133                 21                  0
# 146                  3                  0
# 155                 21                  0
# 165                 21                  0
# 166                  5                  0

# %%
Customer_Payment_DF
# Out:
#                        customerEmail paymentMethodId  \
# 0             josephhoward@yahoo.com       wt07xm68b
# 1             evansjeffery@yahoo.com       y3xp697jx
# 2             evansjeffery@yahoo.com       6krszxc05
# 3             evansjeffery@yahoo.com       5z1szj2he
# 4             evansjeffery@yahoo.com       m52tx8e1s
# 5             evansjeffery@yahoo.com       41ug157xz
# 6             evansjeffery@yahoo.com       4dpg5sx2b
# 7             evansjeffery@yahoo.com       bcx9pa3wf
# 8          andersonwilliam@yahoo.com       8pneoi03z
# 9          andersonwilliam@yahoo.com       dluy3jka0
# 10             rubenjuarez@yahoo.com       pdxjdwui4
# 11                  uchen@malone.com       w1i1zq3rg
# 12                  uchen@malone.com       7o30osjpd
# 13                  uchen@malone.com       76bw9eqg2
# 14                  uchen@malone.com       gehl28i8u
# 15                  uchen@malone.com       olr4zf09x
# 16                  uchen@malone.com       s6escw45g
# 17          robinsoncynthia@dunn.com       wferzj9en
# 18          robinsoncynthia@dunn.com       n5fj5bc0e
# 19      samuel15@saunders-rhodes.com       je76d0ulj
# 20      samuel15@saunders-rhodes.com       dgrnyith9
# 21              johnlowery@gmail.com       8xex97krx
# 22              johnlowery@gmail.com       yxsf33ipw
# 23         jameslandry@rodriguez.com       yk3gx9knx
# 24        ubranch@rivera-parker.info       37264k8rb
# 25            bowenwilliam@yahoo.com       4nt3vg6nr
# 26              ksummers@hotmail.com       anpl44kz2
# 27              ksummers@hotmail.com       12sooz8hm
# 28              ksummers@hotmail.com       ahnb9wv33
# 29              ksummers@hotmail.com       14t4urgqg
# ..                               ...             ...
# 312             johnlowery@gmail.com       8wpdnmsut
# 313             johnlowery@gmail.com       hs3hemcz6
# 314             johnlowery@gmail.com       b001ip7wj
# 315         stevehernandez@gmail.com       8ty2ztfnr
# 316                daniel98@lamb.com       oqkj50e71
# 317              ujackson@harris.com       1phhc3468
# 318              ujackson@harris.com       dby03chrc
# 319          brittanyhicks@jones.com       ti77llxpi
# 320              deborah38@yahoo.com       kzpdmdk05
# 321       andre74@patrick-decker.com       z4jrvn93k
# 322       andre74@patrick-decker.com       sncnkxatz
# 323       andre74@patrick-decker.com       ru0jjkjlt
# 324       andre74@patrick-decker.com       6umtakhhu
# 325        patrickcalderon@russo.net       sptgc1wgt
# 326  mitchellvickie@brewer-jones.com       x644o186l
# 327                sbrown@hughes.biz       wsy5c41nf
# 328                sbrown@hughes.biz       vmktpy2mv
# 329                sbrown@hughes.biz       usu93euvb
# 330             johnlowery@gmail.com       j3foo2l16
# 331             johnlowery@gmail.com       xpd7j7c5g
# 332    ethompson@jackson-sanders.com       b3jl38c9g
# 333    ethompson@jackson-sanders.com       kcg6rzgch
# 334    ethompson@jackson-sanders.com       pj3k9zcc7
# 335    ethompson@jackson-sanders.com       hx496w5tf
# 336    ethompson@jackson-sanders.com       oycs53i0s
# 337    ethompson@jackson-sanders.com       1tmkeoxbm
# 338          dawn05@tucker-brown.com       f0xnu5om9
# 339          dawn05@tucker-brown.com       3zmkegkb8
# 340          dawn05@tucker-brown.com       7yen1m1q8
# 341          dawn05@tucker-brown.com       rh7676yct
#
#      paymentMethodRegistrationFailure paymentMethodType  \
# 0                                True              card
# 1                                True           bitcoin
# 2                               False              card
# 3                               False              card
# 4                               False              card
# 5                               False           bitcoin
# 6                               False              card
# 7                               False              card
# 8                               False              card
# 9                               False              card
# 10                              False              card
# 11                              False         apple pay
# 12                              False         apple pay
# 13                              False         apple pay
# 14                              False              card
# 15                              False              card
# 16                              False              card
# 17                              False            paypal
# 18                              False              card
# 19                              False         apple pay
# 20                              False              card
# 21                              False              card
# 22                              False           bitcoin
# 23                              False              card
# 24                              False            paypal
# 25                              False              card
# 26                              False              card
# 27                              False           bitcoin
# 28                              False              card
# 29                              False              card
# ..                                ...               ...
# 312                             False            paypal
# 313                             False              card
# 314                             False         apple pay
# 315                             False         apple pay
# 316                             False              card
# 317                             False              card
# 318                             False              card
# 319                              True              card
# 320                             False              card
# 321                             False              card
# 322                             False            paypal
# 323                             False              card
# 324                             False         apple pay
# 325                             False         apple pay
# 326                             False              card
# 327                             False              card
# 328                             False              card
# 329                             False              card
# 330                             False              card
# 331                             False              card
# 332                             False              card
# 333                             False              card
# 334                             False           bitcoin
# 335                             False         apple pay
# 336                             False              card
# 337                             False              card
# 338                             False              card
# 339                             False            paypal
# 340                             False              card
# 341                              True         apple pay
#
#            paymentMethodProvider       paymentMethodIssuer
# 0                   JCB 16 digit      Citizens First Banks
# 1                  VISA 16 digit              Solace Banks
# 2                  VISA 16 digit            Vertex Bancorp
# 3    Diners Club / Carte Blanche    His Majesty Bank Corp.
# 4                     Mastercard            Vertex Bancorp
# 5               American Express             Bastion Banks
# 6                        Maestro         Her Majesty Trust
# 7                   JCB 16 digit   Fountain Financial Inc.
# 8                   JCB 16 digit             Bastion Banks
# 9                       Discover    His Majesty Bank Corp.
# 10                       Voyager  Grand Credit Corporation
# 11              American Express  Grand Credit Corporation
# 12                  JCB 16 digit    His Majesty Bank Corp.
# 13                 VISA 16 digit    His Majesty Bank Corp.
# 14                  JCB 16 digit             Bastion Banks
# 15                 VISA 13 digit  Grand Credit Corporation
# 16                  JCB 16 digit              Solace Banks
# 17                  JCB 15 digit                         B
# 18                 VISA 16 digit                         p
# 19                 VISA 13 digit                         x
# 20                  JCB 16 digit                         e
# 21                 VISA 16 digit         Her Majesty Trust
# 22                       Voyager       Bulwark Trust Corp.
# 23                      Discover         Her Majesty Trust
# 24                    Mastercard    His Majesty Bank Corp.
# 25                      Discover                         c
# 26              American Express             Bastion Banks
# 27                       Maestro            Vertex Bancorp
# 28                 VISA 13 digit         Her Majesty Trust
# 29                      Discover            Vertex Bancorp
# ..                           ...                       ...
# 312                 JCB 16 digit            Vertex Bancorp
# 313                      Maestro            Vertex Bancorp
# 314                 JCB 15 digit    His Majesty Bank Corp.
# 315                      Maestro  Grand Credit Corporation
# 316                     Discover  Grand Credit Corporation
# 317                VISA 13 digit       Bulwark Trust Corp.
# 318                   Mastercard           Rose Bancshares
# 319  Diners Club / Carte Blanche       Bulwark Trust Corp.
# 320                VISA 16 digit                         o
# 321                 JCB 16 digit             Bastion Banks
# 322                VISA 16 digit         Her Majesty Trust
# 323                 JCB 16 digit  Grand Credit Corporation
# 324                VISA 16 digit         Her Majesty Trust
# 325             American Express         Her Majesty Trust
# 326                 JCB 16 digit    His Majesty Bank Corp.
# 327                      Voyager                         B
# 328                     Discover                         o
# 329                      Voyager                         x
# 330                 JCB 16 digit            Vertex Bancorp
# 331                 JCB 16 digit   Fountain Financial Inc.
# 332  Diners Club / Carte Blanche             Bastion Banks
# 333                      Maestro      Citizens First Banks
# 334                 JCB 16 digit              Solace Banks
# 335                VISA 16 digit            Vertex Bancorp
# 336                      Voyager      Citizens First Banks
# 337             American Express       Bulwark Trust Corp.
# 338                 JCB 16 digit    His Majesty Bank Corp.
# 339                 JCB 15 digit             Bastion Banks
# 340                VISA 13 digit            Vertex Bancorp
# 341                VISA 13 digit      Citizens First Banks
#
# [342 rows x 6 columns]

# %%
Customer_DF['No_Failed_Orders'] = Customer_DF['customerEmail'].apply(lambda x: Customer_Orders_DF[(Customer_Orders_DF.orderState=='failed') & (Customer_Orders_DF.customerEmail==x)]['orderId'].count())
Customer_DF['No_Success_Orders'] = Customer_DF['customerEmail'].apply(lambda x: Customer_Orders_DF[(Customer_Orders_DF.orderState=='fulfilled') & (Customer_Orders_DF.customerEmail==x)]['orderId'].count())
Customer_DF['No_Pending_Orders'] = Customer_DF['customerEmail'].apply(lambda x: Customer_Orders_DF[(Customer_Orders_DF.orderState=='pending') & (Customer_Orders_DF.customerEmail==x)]['orderId'].count())

# %%
Customer_DF['No_Pending_Orders'] = Customer_DF['customerEmail'].apply(lambda x: Customer_Orders_DF[(Customer_Orders_DF.orderState=='pending') & (Customer_Orders_DF.customerEmail==x)]['orderId'].count())
Customer_DF['Trn_Failed_Ord_Fulfil'] = Customer_DF['customerEmail'].apply(lambda x: ret_trn_fail_ord_success(x))
Customer_DF['Valid_Email'] = Customer_DF['customerEmail'].apply(lambda x: valid_email(x))

# %%
Customer_DF[['card', 'bitcoin', 'apple pay', 'paypal']] = Customer_DF['customerEmail'].apply(lambda x: ret_pay_counts(x))

# %%
Customer_DF['No_Success_Payement_Reg'] = Customer_DF['customerEmail'].apply(lambda x: Customer_Payment_DF[(Customer_Payment_DF.customerEmail==x) & (Customer_Payment_DF.paymentMethodRegistrationFailure==False)].shape[0])

# %%
#cust_transaction_details[cust_transaction_details.customerEmail=='ujackson@harris.com']
#Customer_DF[Customer_DF['customerBillingAddress'].duplicated()]
Customer_DF[Customer_DF.Fraud_Decoded==1]
# Out:
#                          customerEmail         customerPhone  \
# 1               evansjeffery@yahoo.com        1-788-091-7546
# 4                     uchen@malone.com        1-981-877-0870
# 5             robinsoncynthia@dunn.com      +65(5)8997489788
# 6         samuel15@saunders-rhodes.com           05045239487
# 7                 johnlowery@gmail.com          044-642-9860
# 9           ubranch@rivera-parker.info    (772)964-8162x6310
# 10              bowenwilliam@yahoo.com   (128)248-4091x37789
# 15           gonzalesjackson@gmail.com    1-410-373-1228x129
# 23           guerramichael@hotmail.com          299-883-0904
# 29               catherine64@gmail.com      563-396-2038x288
# 32                         9es7t@u6n7x      518.037.7423x366
# 40                johnlowery@gmail.com      737-377-9701x577
# 45                johnlowery@gmail.com      +16(4)9016414340
# 46   jamescampbell@randall-pacheco.biz          599-142-6783
# 50                kristina41@gmail.com        1-836-334-7673
# 55                   uguzman@yahoo.com         (017)893-9493
# 57              feliciabrown@gmail.com         (226)129-2677
# 60               joserowland@jones.com          698-954-1805
# 62                    hj8maoy@1jcfcxs7           03115487766
# 64                 suzanne21@gmail.com        1-043-962-2576
# 65                johnlowery@gmail.com           04712252182
# 68                  cathy42@gibson.com    754.248.6239x43965
# 78                 nancymayo@brown.com      830-346-6543x518
# 79                johnlowery@gmail.com    1-820-539-4726x993
# 80             warrenedward@arnold.com    201.737.5119x64000
# 82               michael57@oconnor.com           06109351281
# 83             jonathan99@stafford.org   (986)656-8692x32356
# 84         lleonard@turner-fleming.com  1-414-937-7421x73705
# 85          whitedavid@jones-lloyd.org          902.047.2861
# 88                shelby24@hotmail.com   (071)934-3315x27613
# ..                                 ...                   ...
# 93      craig83@rasmussen-alvarado.com      122-259-7479x336
# 96                   ukline@spears.biz         (199)535-2932
# 97                 vmiller@hotmail.com          000-734-4774
# 98                   david45@gmail.com         (508)223-3834
# 99              fdavis@wolfe-brown.com    143-448-8038x81186
# 102             mtrevino@gutierrez.net          390.417.8057
# 103              tmcpherson@wright.com  1-804-264-1481x08539
# 104                wdelacruz@yahoo.com      155.688.4242x443
# 105           brooksdustin@knight.info     345.319.0722x7868
# 108                       3fooiar@6eph  1-774-301-9632x42146
# 112                  ugood@mosley.info          869-856-7969
# 115               marywalker@gmail.com          828-124-3490
# 119      amywright@wallace-johnson.com          629.489.3980
# 120                    iray@rogers.com      738-700-9649x102
# 121                  ctaylor@yahoo.com   1-020-923-6697x8718
# 126               koneal@henderson.biz     059.431.5467x7848
# 129               oaguirre@hotmail.com        1-856-006-5150
# 133               johnlowery@gmail.com        1-143-059-1833
# 136           aliciaanthony@martin.com      +77(2)4526373005
# 141           christinemills@mcgee.com         (651)355-4709
# 144                gwilcox@hotmail.com    1-114-728-2835x715
# 151                      1yf0@jedyz63t          463-609-3475
# 153             kwalsh@lopez-gomez.biz           04103378280
# 155               johnlowery@gmail.com    076-099-0630x72770
# 160                deborah38@yahoo.com           06498402936
# 161         andre74@patrick-decker.com          150-073-8610
# 163    mitchellvickie@brewer-jones.com     313-124-3836x3528
# 164                  sbrown@hughes.biz   (250)632-6631x02499
# 165               johnlowery@gmail.com      635.676.0955x524
# 166      ethompson@jackson-sanders.com          962.300.2250
#
#            customerDevice                        customerIPAddress  \
# 1    r0jpm7xaeqqa3kr6mzum                          219.173.211.202
# 4    j0pd24k5h8dl2fqu0cz4                           196.89.235.192
# 5    hbww39m1wenbq4ymjhsx                           43.166.163.164
# 6    up7afvce5v0omniqlevq                              33.67.35.30
# 7    rjb0adai34izqvys4938                           212.144.68.190
# 9    6mpx027neyz6sh04n3ue                             86.16.65.228
# 10   qmntgod0numz62gzbla7                            231.91.253.19
# 15   hmkn4nmfc5q5mgify2zw                            229.2.225.188
# 23   webmbgi39hwejv3d90kt                           245.38.171.222
# 29   myjxxvd3jfn1eymfy50n   1289:d2a9:c65d:8fc7:7be4:129b:d7b:cf7b
# 32   uqdiolg8krd34n4phs18  3617:fa2b:f31e:5b72:59a8:cb1a:d090:edb9
# 40   jz66ap43id2y35ivfqa5  6c21:ac1d:2089:68fa:abb7:8c00:525f:6588
# 45   cdx178qymd6vy77nm4x3                           222.79.159.140
# 46   eaul63h9guyvwuymfn3z                            45.203.99.249
# 50   1a88bvu79nax6873na08                            35.23.150.176
# 55   at92v1f1r3shwbeujiap                           151.245.182.84
# 57   z7xkuohhjbtiqs6q9rk9                          115.137.171.103
# 60   znzp16ko7mtwjfxgrle4                           152.211.139.83
# 62   e3prs7zh4ueieiwlkud7  769a:4538:2bd2:8213:85ed:ca71:1ea3:dcd9
# 64   ewc3gyloi1ing9o64jpt   4834:7ccb:15de:9123:5658:42c3:cc50:79f
# 65   311kdz4c1210iixltk2j   42b3:df19:86fe:abd9:dafe:f6c1:eb76:c72
# 68   c3r2qzqwc9anp6utob7n  7493:ab04:47ff:3a14:67d6:a128:a5b6:1500
# 78   1asmfecu4hbv73a2r5jy                           79.112.154.104
# 79   2in0fh7lep289n8dcbdz                           163.128.139.42
# 80   6py7ewqjkxjw8zjl9eri                            45.203.99.249
# 82   vqvlsaw0j6p0r8sij1qs                             30.23.223.15
# 83   1mt65bhu4bzyrmzeitz6    ecc1:e4b8:65e1:d1e:bf58:b09d:3c50:509
# 84   yfpqgg5oxsn107veaala                             97.111.97.42
# 85   jvab5ehh3y5u4spybjm4                           95.228.108.171
# 88   obb41ux0zfa2td5ajo9s                            45.203.99.249
# ..                    ...                                      ...
# 93   s93o0wj3eqd9whcy9ng3                           35.212.254.226
# 96   vv7fwhdfrxaeozga5be6    990a:643c:1936:30db:f90:90fe:c1e0:47c
# 97   b1tjk5s0j9ybj1qpt3ik                             164.79.214.9
# 98   l6qv05oe0h0j78kx84ex  9d8d:535b:36fc:8773:bec0:8fa5:3206:4cb5
# 99   gt7k74rsgtklj0zjx8gl                           69.138.168.116
# 102  pycmjs4dqylc8rb0s9pt  6694:eef3:c2a3:9181:42a0:2df9:b2c1:2acd
# 103  ui77ukzr5lnqpajdk03u  296d:59fe:a919:21ac:16dd:96f5:10b3:4f83
# 104  fmm4yabu9llergl9qbl9   cd18:5626:a1c4:7e99:addf:368e:c98:e772
# 105  dhe9trcjv1fyr2vr18q2                           172.69.105.137
# 108  by46esafzb52tuqcy9d1                             181.88.44.76
# 112  qdrwvtooysq6q0i0asm7   7847:656d:453b:4e2d:8493:82f8:cff:502e
# 115  kah1gtidszvnkih1lvtd                           11.165.157.167
# 119  n29he2b6a841zcbiw2i9                           254.155.117.48
# 120  qkkvc35qa3mx8g1t1jr2  4338:887b:3e9b:f16d:7257:2a21:6559:e9a4
# 121  uu141ykhyig0cj3s98jr  dda2:66e0:4279:3c1b:ac29:4cbb:5ea3:c26b
# 126  gcfo5uheb9mugbstbjez                           85.188.105.126
# 129  cvtpgtclxkvcwvr16cyd  ae37:8e14:bfc1:43c4:7dde:7b9e:ca7f:4721
# 133  tyijaify2hqadwslejyr   e4c:fb48:8ee2:9819:6ae8:8d3f:3b6a:a788
# 136  9iac2it77dm615ucymx3                           110.221.131.62
# 141  zbn9it3s7yl69bjtrnqf                            45.203.99.249
# 144  3pfhcvbn8itarkhxl087                           168.56.122.190
# 151  j3a0155srqw0yeqvbgps  1fe2:1fa3:2a6f:845d:1037:2dac:2831:9d50
# 153  mdoe6wib243y09uaj95z  3162:1f06:9114:56d1:f5e8:bf3a:6ad0:b6f2
# 155  6qy6oa3nqutsyyxzc54c  f259:657f:f329:2fca:c06c:8b57:d6ac:2380
# 160  vc71dbmrdaz78jgi7nhl  8f3c:9e11:63b4:73bb:20d1:86c7:ab70:2e04
# 161  4gfo1e3xeirjanhwko92   d89c:db0:5ff9:a150:9e6c:482d:c900:fb33
# 163  ecu7ezz0ue67v3fce1o3                           181.90.104.120
# 164  xgv918sclaz40qlp2fee                               16.166.2.0
# 165  969zz9zdj8z4gns4sx5p   f82c:811f:8a02:e2d6:79b:fcaa:42de:570b
# 166  navessqcnmc9csfjn5cj                          203.246.172.244
#
#                                 customerBillingAddress  No_Transactions  \
# 1    356 Elizabeth Inlet Suite 120\nPort Joshuabury...                3
# 4    148 Russell Lodge Apt. 445\nPort Jenniferside,...                7
# 5    65233 Hutchinson Mountains\nMartinezside, OR 7...                1
# 6           3960 Emily Fort\nStaceytown, AR 21817-3325                2
# 7     484 Pamela Pass\nLake Jessicaview, WI 12942-9074               28
# 9    6974 Robertson Common Apt. 902\nPort Juanside,...                0
# 10             27061 Wright Forks\nCraigland, MN 59915                6
# 15             566 Courtney Stream\nReedland, NH 84853                4
# 23   13553 Michelle Freeway Apt. 290\nTammyhaven, G...                0
# 29   372 Michael Club Suite 553\nHerrerafort, MH 52953                5
# 32        63978 Luis Ports\nYvonneville, NE 63736-2980                2
# 40   08238 Kyle Squares Suite 893\nMillermouth, IN ...               28
# 45             77711 Pamela Ridge\nNew Kayla, IL 27182               28
# 46       29408 Lisa Lock\nPort Jennifer, LA 26501-7040                7
# 50   5769 Ronald Brook Suite 963\nLake Jasonfurt, M...                7
# 55   9596 Christian Bridge\nWest Nicholasbury, OR 9...                1
# 57   49680 Brian Squares Apt. 122\nPort Walterburgh...                1
# 60     1292 Tricia Key Suite 062\nMarthabury, KS 40445                4
# 62   872 Ashley Island Apt. 254\nEast Anthonytown, ...                6
# 64        398 Latasha Canyon\nKathyland, LA 36717-2161                5
# 65   11704 Andrew Villages Apt. 035\nJamesfurt, OR ...               28
# 68   046 Carson Crescent\nSouth Jacksonview, NV 228...                3
# 78   6927 Nathan Mountains\nNorth April, PA 95355-9109                7
# 79             814 Wagner Union\nAshleymouth, HI 35617               28
# 80   49680 Brian Squares Apt. 122\nPort Walterburgh...                4
# 82          905 David Rest\nNicolemouth, OK 53015-0063                0
# 83               4913 Wright Ranch\nRoymouth, VI 48629                2
# 84      96103 Riley Walks\nMichellefort, ID 98085-6066               11
# 85      881 Jessica Ford\nEricksonhaven, FL 83492-3227                5
# 88      3271 Cynthia Groves\nPort Jeremyberg, CO 27305                5
# ..                                                 ...              ...
# 93   10068 Adam Rapids Suite 792\nRileyburgh, GA 11372                2
# 96     2038 Billy Turnpike\nBarreraside, AR 77704-0733                0
# 97               PSC 9111, Box 9839\nAPO AA 57283-9646               10
# 98   5360 Adams Falls Suite 829\nHensleymouth, WV 8...               10
# 99   6609 Hannah Road Suite 577\nRichardchester, AL...                3
# 102      767 Tiffany Drive\nMirandaview, OH 42972-3228                1
# 103  7956 Alex Avenue Apt. 593\nPort Michael, OK 41350               13
# 104       3074 Caroline Oval\nLake Maryburgh, MA 15880                4
# 105  8554 John Forge Apt. 284\nPort Kimberlyburgh, ...                1
# 108  942 Hopkins Loaf Suite 128\nPort Clifford, AK ...                0
# 112  88979 Jennifer Field Suite 069\nRobertchester,...                2
# 115            4025 Rivera Mill\nWest Justin, UT 11158                4
# 119     403 Anna Center Apt. 947\nMeganhaven, GA 46627                6
# 120              Unit 4843 Box 7401\nDPO AP 92304-9120                5
# 121   87096 Warren Turnpike\nHowellview, WA 74727-2420                8
# 126  056 Megan Trail Suite 355\nWest Zachary, GU 51...                4
# 129  719 Jeremy Flat Apt. 914\nAlexanderport, IA 97...                1
# 133  518 Wood Mews Apt. 970\nDillonstad, NE 43317-3945               28
# 136         265 Marisa Keys\nLynchmouth, WV 63252-7526                3
# 141  5156 Greene Park Apt. 748\nNew Sandra, CA 1480...                5
# 144  77436 Denise Key Suite 828\nMayschester, AR 65...                7
# 151  12350 Nicholas Greens\nLawsonborough, NC 70237...               10
# 153         0008 Jessica Stream\nMcbridetown, MH 04017                3
# 155  687 Rogers Bridge Suite 780\nValdezburgh, IN 2...               28
# 160  391 Rogers Flats Apt. 287\nNorth Rickchester, ...                1
# 161  55197 Jeffrey Burgs Suite 700\nGardnerport, VA...                5
# 163  829 Ramirez Dam Suite 648\nGatesview, OR 55669...                3
# 164  9472 Pacheco Islands Suite 940\nDrewburgh, AZ ...                6
# 165           548 Bryant Inlet\nVeronicaside, OK 00522               28
# 166   16953 Jennifer Springs\nKathybury, IL 02095-3215                8
#
#      No_Orders  No_Payments  Fraud  Fraud_Decoded  ...  No_Pending_Orders  \
# 1            3            7   True              1  ...                  0
# 4            7            6   True              1  ...                  0
# 5            1            2   True              1  ...                  1
# 6            1            2   True              1  ...                  0
# 7           23           11   True              1  ...                  0
# 9            0            1   True              1  ...                  0
# 10           5            1   True              1  ...                  1
# 15           4            1   True              1  ...                  0
# 23           0            1   True              1  ...                  0
# 29           4            6   True              1  ...                  1
# 32           1            1   True              1  ...                  0
# 40          23           11   True              1  ...                  0
# 45          23           11   True              1  ...                  0
# 46           3            2   True              1  ...                  0
# 50           6            3   True              1  ...                  0
# 55           1            1   True              1  ...                  0
# 57           1            1   True              1  ...                  0
# 60           4            6   True              1  ...                  0
# 62           5            2   True              1  ...                  0
# 64           3            2   True              1  ...                  0
# 65          23           11   True              1  ...                  0
# 68           3           15   True              1  ...                  0
# 78           6            2   True              1  ...                  1
# 79          23           11   True              1  ...                  0
# 80           4           14   True              1  ...                  0
# 82           0            2   True              1  ...                  0
# 83           2            1   True              1  ...                  1
# 84           8            1   True              1  ...                  2
# 85           5            4   True              1  ...                  0
# 88           4            2   True              1  ...                  0
# ..         ...          ...    ...            ...  ...                ...
# 93           2           13   True              1  ...                  0
# 96           0            3   True              1  ...                  0
# 97           8            1   True              1  ...                  0
# 98           8            5   True              1  ...                  0
# 99           3            3   True              1  ...                  0
# 102          1            4   True              1  ...                  1
# 103          8            1   True              1  ...                  1
# 104          4            1   True              1  ...                  0
# 105          1            2   True              1  ...                  0
# 108          0            1   True              1  ...                  0
# 112          2            4   True              1  ...                  0
# 115          3            3   True              1  ...                  0
# 119          6            1   True              1  ...                  0
# 120          5            5   True              1  ...                  0
# 121          6            6   True              1  ...                  0
# 126          4            1   True              1  ...                  0
# 129          1            4   True              1  ...                  0
# 133         23           11   True              1  ...                  0
# 136          3            1   True              1  ...                  0
# 141          5            2   True              1  ...                  0
# 144          6            5   True              1  ...                  2
# 151          5            4   True              1  ...                  0
# 153          3            2   True              1  ...                  0
# 155         23           11   True              1  ...                  0
# 160          1            1   True              1  ...                  0
# 161          4            4   True              1  ...                  0
# 163          3            1   True              1  ...                  0
# 164          5            3   True              1  ...                  0
# 165         23           11   True              1  ...                  0
# 166          6            6   True              1  ...                  0
#
#      Is_Duplicate_IP  Is_Duplicate_Address  Trn_Failed_Ord_Fulfil  \
# 1                  0                     0                      1
# 4                  0                     0                      2
# 5                  0                     0                      0
# 6                  0                     0                      0
# 7                  0                     0                      1
# 9                  0                     0                      0
# 10                 0                     0                      1
# 15                 0                     0                      0
# 23                 0                     0                      0
# 29                 0                     0                      0
# 32                 0                     0                      0
# 40                 0                     0                      1
# 45                 0                     0                      1
# 46                 1                     0                      0
# 50                 0                     0                      0
# 55                 0                     0                      1
# 57                 0                     1                      0
# 60                 0                     0                      0
# 62                 0                     0                      0
# 64                 0                     0                      0
# 65                 0                     0                      1
# 68                 0                     0                      0
# 78                 0                     0                      0
# 79                 0                     0                      1
# 80                 1                     1                      0
# 82                 0                     0                      0
# 83                 0                     0                      0
# 84                 0                     0                      0
# 85                 0                     0                      0
# 88                 1                     0                      0
# ..               ...                   ...                    ...
# 93                 0                     0                      1
# 96                 0                     0                      0
# 97                 0                     0                      1
# 98                 0                     0                      1
# 99                 0                     0                      0
# 102                0                     0                      0
# 103                0                     0                      1
# 104                0                     0                      1
# 105                0                     0                      0
# 108                0                     0                      0
# 112                0                     0                      0
# 115                0                     0                      0
# 119                0                     0                      1
# 120                0                     0                      0
# 121                0                     0                      0
# 126                0                     0                      0
# 129                0                     0                      0
# 133                0                     0                      1
# 136                0                     0                      0
# 141                1                     0                      0
# 144                0                     0                      0
# 151                0                     0                      0
# 153                0                     0                      0
# 155                0                     0                      1
# 160                0                     0                      0
# 161                0                     0                      0
# 163                0                     0                      0
# 164                0                     0                      0
# 165                0                     0                      1
# 166                0                     0                      0
#
#      Valid_Email  No_Success_Payement_Reg  card  bitcoin  apple pay  paypal
# 1              1                        6     5        1          0       0
# 4              1                        6     3        0          3       0
# 5              1                        2     1        0          0       1
# 6              1                        2     1        0          1       0
# 7              1                       11     8        1          1       1
# 9              1                        1     0        0          0       1
# 10             1                        1     1        0          0       0
# 15             1                        1     0        0          1       0
# 23             1                        1     0        0          0       1
# 29             1                        6     4        2          0       0
# 32             0                        1     1        0          0       0
# 40             1                       11     8        1          1       1
# 45             1                       11     8        1          1       1
# 46             1                        2     2        0          0       0
# 50             1                        3     2        0          1       0
# 55             1                        1     1        0          0       0
# 57             1                        1     1        0          0       0
# 60             1                        5     5        0          0       0
# 62             0                        2     1        0          0       1
# 64             1                        2     1        1          0       0
# 65             1                       11     8        1          1       1
# 68             1                       12     9        0          1       2
# 78             1                        1     0        0          1       0
# 79             1                       11     8        1          1       1
# 80             1                       10     7        0          3       0
# 82             1                        2     1        1          0       0
# 83             1                        1     1        0          0       0
# 84             1                        1     1        0          0       0
# 85             1                        3     2        0          1       0
# 88             1                        1     1        0          0       0
# ..           ...                      ...   ...      ...        ...     ...
# 93             1                       11     7        2          2       0
# 96             1                        3     1        1          0       1
# 97             1                        1     1        0          0       0
# 98             1                        5     3        1          1       0
# 99             1                        2     2        0          0       0
# 102            1                        2     2        0          0       0
# 103            1                        0     0        0          0       0
# 104            1                        1     1        0          0       0
# 105            1                        2     1        1          0       0
# 108            0                        1     1        0          0       0
# 112            1                        4     2        0          1       1
# 115            1                        3     2        1          0       0
# 119            1                        0     0        0          0       0
# 120            1                        5     4        1          0       0
# 121            1                        6     6        0          0       0
# 126            1                        1     0        1          0       0
# 129            1                        4     2        0          2       0
# 133            1                       11     8        1          1       1
# 136            1                        1     1        0          0       0
# 141            1                        2     1        0          0       1
# 144            1                        4     4        0          0       0
# 151            0                        4     2        0          0       2
# 153            1                        1     0        0          0       1
# 155            1                       11     8        1          1       1
# 160            1                        1     1        0          0       0
# 161            1                        4     2        0          1       1
# 163            1                        1     1        0          0       0
# 164            1                        3     3        0          0       0
# 165            1                       11     8        1          1       1
# 166            1                        6     4        1          1       0
#
# [61 rows x 25 columns]

# %% [markdown]
# <h2>Data Splitting and Model training</h2>

# %%
data = Customer_DF[['No_Transactions', 'No_Orders', 'No_Payments', 'Fraud_Decoded', 'Is_Duplicate_Name',
       'No_Successfull_Transactions', 'No_Failed_Transactions',
       'No_Failed_Orders', 'No_Success_Orders', 'No_Pending_Orders',
       'Is_Duplicate_IP', 'Is_Duplicate_Address', 'Trn_Failed_Ord_Fulfil',
       'Valid_Email', 'No_Success_Payement_Reg', 'card', 'bitcoin',
       'apple pay', 'paypal']].copy()

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(data.loc[:, data.columns != 'Fraud_Decoded'], data[['Fraud_Decoded']],
                                                    test_size=0.3,
                                                    random_state=0,
                                                    stratify=data[['Fraud_Decoded']])

# %%
def plot_confusion_matrix(test_y, predict_y):
    C = confusion_matrix(test_y, predict_y)
    
    
    A =(((C.T)/(C.sum(axis=1))).T)
    B =(C/C.sum(axis=0))
    labels = ['Fraud','Not Fraud']#[0,1,2,3,4]
    
    
    print("-"*20, "Confusion matrix", "-"*20)
    plt.figure(figsize=(15,7))
    sns.heatmap(C, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()

# %%
def tuning(model, parameters, parameter_name, train_data_x, train_data_y, plot_values,is_xgb=False):
    grid = GridSearchCV(model, parameters, cv = 3, scoring = 'f1_macro')
    grid.fit(train_data_x, train_data_y)
    
    
    results = pd.DataFrame(grid.cv_results_)           #storing results of gridseachcv in a dataframe to access its elements
    params = results['params']                         #storing combination of parameters used by model in params
    score_tr_array = results['mean_train_score']         #storing scores on train data of model
    score_cv_array = results['mean_test_score']          #storing scores on cv data of model
    for i in range(len(params)):
        print("For", params[i]," acc of Train data is", score_tr_array[i],"and acc of CV data is", score_cv_array[i])
    
    
    print('Best Parameter is ',  grid.best_params_)
    print('Best F1 Score is ',  grid.best_score_)
    if not is_xgb:
        plt.xlabel(parameter_name)
        plt.title('Cross Validation')
        plt.plot(np.log10(plot_values),grid.cv_results_['mean_train_score'])
        plt.plot(np.log10(plot_values),grid.cv_results_['mean_test_score'])
        plt.legend(['Train Accuracy', 'CV Accuracy'])
        plt.show()
    
    return grid.best_params_

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score, log_loss, roc_auc_score, classification_report

from collections import Counter, defaultdict
import numpy as np

# %% [markdown]
# <h2>Logistic Regression</h2>

# %%
from sklearn.linear_model import LogisticRegression


model = LogisticRegression()
alpha = [0.00001,0.0001,0.001,0.01,0.1,1,10,100,1000,10000]
alphas = {'C' : alpha}
best_params = tuning(model, alphas, 'C', x_train, y_train, alpha)

best_alpha = best_params['C']
clf = LogisticRegression(C = best_alpha).fit(x_train, y_train)
y_pred = clf.predict(x_test)
y_pred_proba = clf.predict_proba(x_test)

nb_uni_bow_raw_acc = accuracy_score(y_test, y_pred)
nb_uni_bow_raw_f1 = f1_score(y_test, y_pred, average = 'macro')
nb_uni_bow_raw_ll = log_loss(y_test, y_pred_proba)

print('Accuracy of model on testing data is', nb_uni_bow_raw_acc)
print('F1 Score of model on testing data is', nb_uni_bow_raw_f1)
print('Log loss of model on testing data is', nb_uni_bow_raw_ll)
# Out:
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split1_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split2_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('std_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# For {'C': 1e-05}  acc of Train data is 0.38697165706545594 and acc of CV data is 0.37153650634042784
# For {'C': 0.0001}  acc of Train data is 0.38697165706545594 and acc of CV data is 0.3754616271133747
# For {'C': 0.001}  acc of Train data is 0.47574215085031807 and acc of CV data is 0.4507341130749424
# For {'C': 0.01}  acc of Train data is 0.6743787833668956 and acc of CV data is 0.6534661763988278
# For {'C': 0.1}  acc of Train data is 0.742468214252532 and acc of CV data is 0.6644334975369458
# For {'C': 1}  acc of Train data is 0.7554584742837497 and acc of CV data is 0.6794491520072623
# For {'C': 10}  acc of Train data is 0.7641435073196079 and acc of CV data is 0.6739669461555008
# For {'C': 100}  acc of Train data is 0.7623019607065963 and acc of CV data is 0.6836489107287695
# For {'C': 1000}  acc of Train data is 0.7706167499440674 and acc of CV data is 0.6836489107287695
# For {'C': 10000}  acc of Train data is 0.7706167499440674 and acc of CV data is 0.6836489107287695
# Best Parameter is  {'C': 100}
# Best F1 Score is  0.6836489107287695
# Accuracy of model on testing data is 0.8235294117647058
# F1 Score of model on testing data is 0.7984189723320159
# Log loss of model on testing data is 0.3665741195775375
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
plot_confusion_matrix(y_test, y_pred)
# Out:
# -------------------- Confusion matrix --------------------

# %%
weights = clf.coef_.argsort()
new_weights = weights[0][:-1]
pos_weights = np.take(x_train.columns,new_weights[-5:])
print("*******************Top 5 positive features*****************************")
print(pos_weights.values)
print("************************************************************************")

weights = clf.coef_.argsort()
new_weights = weights[0][:-1]
pos_weights = np.take(x_train.columns,new_weights[:5])
print("*******************Top 5 Negative features*****************************")
print(pos_weights.values)
print("************************************************************************")
# Out:
# *******************Top 5 positive features*****************************
# ['No_Failed_Transactions' 'No_Failed_Orders' 'No_Pending_Orders'
#  'No_Orders' 'Is_Duplicate_IP']
# ************************************************************************
# *******************Top 5 Negative features*****************************
# ['Valid_Email' 'Trn_Failed_Ord_Fulfil' 'No_Successfull_Transactions'
#  'No_Transactions' 'card']
# ************************************************************************

# %% [markdown]
# <h2>SVM</h2>

# %%
from sklearn.svm import SVC


model = SVC( kernel='linear')
alpha = [0.00001,0.0001,0.001,0.01,0.1,1,10,100,1000,10000]
alphas = {'C' : alpha}
best_params = tuning(model, alphas, 'C', x_train, y_train, alpha)

best_alpha = best_params['C']
clf = SVC( kernel='linear',C = best_alpha,probability=True).fit(x_train, y_train)
y_pred = clf.predict(x_test)
y_pred_proba = clf.predict_proba(x_test)

nb_uni_bow_raw_acc = accuracy_score(y_test, y_pred)
nb_uni_bow_raw_f1 = f1_score(y_test, y_pred, average = 'macro')
nb_uni_bow_raw_ll = log_loss(y_test, y_pred_proba)

print('Accuracy of model on testing data is', nb_uni_bow_raw_acc)
print('F1 Score of model on testing data is', nb_uni_bow_raw_f1)
print('Log loss of model on testing data is', nb_uni_bow_raw_ll)
# Out:
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split1_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split2_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('std_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# For {'C': 1e-05}  acc of Train data is 0.39062500000000006 and acc of CV data is 0.39062500000000006
# For {'C': 0.0001}  acc of Train data is 0.39062500000000006 and acc of CV data is 0.39062500000000006
# For {'C': 0.001}  acc of Train data is 0.5475860889040969 and acc of CV data is 0.526008174584247
# For {'C': 0.01}  acc of Train data is 0.5858496702869114 and acc of CV data is 0.5628958687300057
# For {'C': 0.1}  acc of Train data is 0.7031810652753858 and acc of CV data is 0.6513347309573726
# For {'C': 1}  acc of Train data is 0.7777005246075118 and acc of CV data is 0.6871470202898916
# For {'C': 10}  acc of Train data is 0.7768785919212284 and acc of CV data is 0.630527025442128
# For {'C': 100}  acc of Train data is 0.7768785919212284 and acc of CV data is 0.630527025442128
# For {'C': 1000}  acc of Train data is 0.7768785919212284 and acc of CV data is 0.630527025442128
# For {'C': 10000}  acc of Train data is 0.7768785919212284 and acc of CV data is 0.630527025442128
# Best Parameter is  {'C': 1}
# Best F1 Score is  0.6871470202898916
# Accuracy of model on testing data is 0.803921568627451
# F1 Score of model on testing data is 0.7538610038610039
# Log loss of model on testing data is 0.45119490216018304
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
plot_confusion_matrix(y_test, y_pred)
# Out:
# -------------------- Confusion matrix --------------------

# %%
weights = clf.coef_.argsort()
new_weights = weights[0][:-1]
pos_weights = np.take(x_train.columns,new_weights[-5:])
print("*******************Top 5 positive features*****************************")
print(pos_weights.values)
print("************************************************************************")

weights = clf.coef_.argsort()
new_weights = weights[0][:-1]
pos_weights = np.take(x_train.columns,new_weights[:5])
print("*******************Top 5 Negative features*****************************")
print(pos_weights.values)
print("************************************************************************")
# Out:
# *******************Top 5 positive features*****************************
# ['No_Failed_Orders' 'No_Payments' 'apple pay' 'No_Orders'
#  'Is_Duplicate_IP']
# ************************************************************************
# *******************Top 5 Negative features*****************************
# ['Valid_Email' 'No_Successfull_Transactions' 'No_Transactions' 'paypal'
#  'Trn_Failed_Ord_Fulfil']
# ************************************************************************

# %% [markdown]
# <h2>Random Forest</h2>

# %%
from sklearn.ensemble import RandomForestClassifier


model=RandomForestClassifier()
alpha = [100,150,200,250,300]
alphas = {'n_estimators' : alpha}
best_params = tuning(model, alphas, 'n_estimators', x_train, y_train, alpha)

best_alpha = best_params['n_estimators']
clf = RandomForestClassifier(n_estimators=best_alpha).fit(x_train, y_train)
y_pred = clf.predict(x_test)
y_pred_proba = clf.predict_proba(x_test)

nb_uni_bow_raw_acc = accuracy_score(y_test, y_pred)
nb_uni_bow_raw_f1 = f1_score(y_test, y_pred, average = 'macro')
nb_uni_bow_raw_ll = log_loss(y_test, y_pred_proba)

print('Accuracy of model on testing data is', nb_uni_bow_raw_acc)
print('F1 Score of model on testing data is', nb_uni_bow_raw_f1)
print('Log loss of model on testing data is', nb_uni_bow_raw_ll)
# Out:
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:740: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split1_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split2_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('std_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# For {'n_estimators': 100}  acc of Train data is 0.9718373144503992 and acc of CV data is 0.7420169934120108
# For {'n_estimators': 150}  acc of Train data is 0.9718373144503992 and acc of CV data is 0.7300102382291551
# For {'n_estimators': 200}  acc of Train data is 0.971992413527067 and acc of CV data is 0.7161004868798142
# For {'n_estimators': 250}  acc of Train data is 0.9718373144503992 and acc of CV data is 0.7027717103931429
# For {'n_estimators': 300}  acc of Train data is 0.9718373144503992 and acc of CV data is 0.7099485098340934
# Best Parameter is  {'n_estimators': 100}
# Best F1 Score is  0.7420169934120108
# Accuracy of model on testing data is 0.7843137254901961
# F1 Score of model on testing data is 0.7350023618327822
# Log loss of model on testing data is 0.4674795566534604
# C:\Users\LENOVO\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # Remove the CWD from sys.path while we load stuff.

# %%
plot_confusion_matrix(y_test, y_pred)
# Out:
# -------------------- Confusion matrix --------------------

# %%
feat_importances = pd.Series(clf.feature_importances_, index=x_train.columns)
feat_importances.nlargest(10).plot(kind='barh')

# %% [markdown]
# <h2>XGBOOST Model</h2>

# %%
from xgboost import XGBClassifier
model=XGBClassifier()
parameters = { #when use hyperthread, xgboost may become slower
              'learning_rate': [ 0.05, .07,0.01], #so called `eta` value
              'max_depth': [5, 6, 7],
              'n_estimators': [10,50,100,500]}
best_params = tuning(model, parameters, 'n_estimators', x_train, y_train, alpha,is_xgb=True)

best_alpha = best_params['n_estimators']
clf = RandomForestClassifier(n_estimators=best_alpha).fit(x_train, y_train)
y_pred = clf.predict(x_test)
y_pred_proba = clf.predict_proba(x_test)

nb_uni_bow_raw_acc = accuracy_score(y_test, y_pred)
nb_uni_bow_raw_f1 = f1_score(y_test, y_pred, average = 'macro')
nb_uni_bow_raw_ll = log_loss(y_test, y_pred_proba)

print('Accuracy of model on testing data is', nb_uni_bow_raw_acc)
print('F1 Score of model on testing data is', nb_uni_bow_raw_f1)
print('Log loss of model on testing data is', nb_uni_bow_raw_ll)
# Out:
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split1_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split2_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('std_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # Remove the CWD from sys.path while we load stuff.
# For {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 10}  acc of Train data is 0.801504545285579 and acc of CV data is 0.6341735873404027
# For {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 50}  acc of Train data is 0.8580769861256877 and acc of CV data is 0.6858001485194467
# For {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 100}  acc of Train data is 0.8856987661473936 and acc of CV data is 0.6930827067669173
# For {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 500}  acc of Train data is 0.942451449411263 and acc of CV data is 0.6900112930547713
# For {'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 10}  acc of Train data is 0.801504545285579 and acc of CV data is 0.6341735873404027
# For {'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 50}  acc of Train data is 0.876382782764446 and acc of CV data is 0.6909099578563332
# For {'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 100}  acc of Train data is 0.8859431623116536 and acc of CV data is 0.7070285562390826
# For {'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 500}  acc of Train data is 0.942451449411263 and acc of CV data is 0.6717358294510895
# For {'learning_rate': 0.05, 'max_depth': 7, 'n_estimators': 10}  acc of Train data is 0.801504545285579 and acc of CV data is 0.6341735873404027
# For {'learning_rate': 0.05, 'max_depth': 7, 'n_estimators': 50}  acc of Train data is 0.8817932889537684 and acc of CV data is 0.6780250289022219
# For {'learning_rate': 0.05, 'max_depth': 7, 'n_estimators': 100}  acc of Train data is 0.8859431623116536 and acc of CV data is 0.7070285562390826
# For {'learning_rate': 0.05, 'max_depth': 7, 'n_estimators': 500}  acc of Train data is 0.942451449411263 and acc of CV data is 0.7115647605843685
# For {'learning_rate': 0.07, 'max_depth': 5, 'n_estimators': 10}  acc of Train data is 0.8180906492989269 and acc of CV data is 0.6275259140260625
# For {'learning_rate': 0.07, 'max_depth': 5, 'n_estimators': 50}  acc of Train data is 0.8637840238282445 and acc of CV data is 0.6647378313491383
# For {'learning_rate': 0.07, 'max_depth': 5, 'n_estimators': 100}  acc of Train data is 0.8966078041161799 and acc of CV data is 0.6627378469483732
# For {'learning_rate': 0.07, 'max_depth': 5, 'n_estimators': 500}  acc of Train data is 0.9474970573980475 and acc of CV data is 0.6926475832272935
# For {'learning_rate': 0.07, 'max_depth': 6, 'n_estimators': 10}  acc of Train data is 0.8138089262254816 and acc of CV data is 0.6341735873404027
# For {'learning_rate': 0.07, 'max_depth': 6, 'n_estimators': 50}  acc of Train data is 0.8814108298935867 and acc of CV data is 0.6838417430522694
# For {'learning_rate': 0.07, 'max_depth': 6, 'n_estimators': 100}  acc of Train data is 0.9064191248708969 and acc of CV data is 0.6746226578527921
# For {'learning_rate': 0.07, 'max_depth': 6, 'n_estimators': 500}  acc of Train data is 0.952439495432627 and acc of CV data is 0.6839790344479177
# For {'learning_rate': 0.07, 'max_depth': 7, 'n_estimators': 10}  acc of Train data is 0.8138089262254816 and acc of CV data is 0.6341735873404027
# For {'learning_rate': 0.07, 'max_depth': 7, 'n_estimators': 50}  acc of Train data is 0.8859431623116536 and acc of CV data is 0.6780250289022219
# For {'learning_rate': 0.07, 'max_depth': 7, 'n_estimators': 100}  acc of Train data is 0.9115767099174943 and acc of CV data is 0.6698958935801042
# For {'learning_rate': 0.07, 'max_depth': 7, 'n_estimators': 500}  acc of Train data is 0.9474970573980475 and acc of CV data is 0.679618221284888
# For {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 10}  acc of Train data is 0.7957554041614935 and acc of CV data is 0.6341735873404027
# For {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}  acc of Train data is 0.801504545285579 and acc of CV data is 0.6341735873404027
# For {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100}  acc of Train data is 0.8223723723723723 and acc of CV data is 0.6400047395483663
# For {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 500}  acc of Train data is 0.8912221506483037 and acc of CV data is 0.6930827067669173
# For {'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 10}  acc of Train data is 0.7957554041614935 and acc of CV data is 0.6341735873404027
# For {'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 50}  acc of Train data is 0.7972922082611907 and acc of CV data is 0.6394483126151279
# For {'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 100}  acc of Train data is 0.830167009838195 and acc of CV data is 0.6400047395483663
# For {'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 500}  acc of Train data is 0.8859431623116536 and acc of CV data is 0.7070285562390826
# For {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 10}  acc of Train data is 0.7957554041614935 and acc of CV data is 0.6341735873404027
# For {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 50}  acc of Train data is 0.7972922082611907 and acc of CV data is 0.6394483126151279
# For {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100}  acc of Train data is 0.8358032726506929 and acc of CV data is 0.6400047395483663
# For {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 500}  acc of Train data is 0.8904506420082742 and acc of CV data is 0.7070285562390826
# Best Parameter is  {'learning_rate': 0.05, 'max_depth': 7, 'n_estimators': 500}
# Best F1 Score is  0.7115647605843685
# Accuracy of model on testing data is 0.7843137254901961
# F1 Score of model on testing data is 0.745115856428896
# Log loss of model on testing data is 0.4629684498971438

# %%
plot_confusion_matrix(y_test, y_pred)
# Out:
# -------------------- Confusion matrix --------------------

# %%
feat_importances = pd.Series(clf.feature_importances_, index=x_train.columns)
feat_importances.nlargest(10).plot(kind='barh')

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=0)
X_2d = tsne.fit_transform(X)

target_ids = range(2)

from matplotlib import pyplot as plt
plt.figure(figsize=(6, 5))
colors = 'r', 'g'
for i, c, label in zip(target_ids, colors, ['True','False']):
    plt.scatter(X_2d[y == i, 0], X_2d[y == i, 1], c=c, label=label)
plt.legend()
plt.show()

# %%
Customer_DF.to_csv('Customer_DF.csv')

# %%
Total_Amount_of_Transactions_Success
Total_Amount
Total_orders
Success_orders
Failure_Orders

# %%
Customer_Orders_DF.head()
# Out:
#             customerEmail orderId  orderAmount orderState  \
# 0  josephhoward@yahoo.com  vjbdvd           18    pending
# 1  josephhoward@yahoo.com  yp6x27           26  fulfilled
# 2  evansjeffery@yahoo.com  nlghpa           45  fulfilled
# 3  evansjeffery@yahoo.com  uw0eeb           23  fulfilled
# 4  evansjeffery@yahoo.com  bn44oh           43  fulfilled
#
#                                 orderShippingAddress
# 0            5493 Jones Islands\nBrownside, CA 51896
# 1            5493 Jones Islands\nBrownside, CA 51896
# 2      898 Henry Ports\nNew Keithview, CA 95893-2497
# 3  356 Elizabeth Inlet Suite 120\nPort Joshuabury...
# 4         5093 Bryan Forks\nJoshuaton, FM 01565-9801

# %%
Customer_transaction_DF.shape
# Out:
# (623, 6)

# %%
Customer_Payment_DF
# Out:
#                        customerEmail paymentMethodId  \
# 0             josephhoward@yahoo.com       wt07xm68b
# 1             evansjeffery@yahoo.com       y3xp697jx
# 2             evansjeffery@yahoo.com       6krszxc05
# 3             evansjeffery@yahoo.com       5z1szj2he
# 4             evansjeffery@yahoo.com       m52tx8e1s
# 5             evansjeffery@yahoo.com       41ug157xz
# 6             evansjeffery@yahoo.com       4dpg5sx2b
# 7             evansjeffery@yahoo.com       bcx9pa3wf
# 8          andersonwilliam@yahoo.com       8pneoi03z
# 9          andersonwilliam@yahoo.com       dluy3jka0
# 10             rubenjuarez@yahoo.com       pdxjdwui4
# 11                  uchen@malone.com       w1i1zq3rg
# 12                  uchen@malone.com       7o30osjpd
# 13                  uchen@malone.com       76bw9eqg2
# 14                  uchen@malone.com       gehl28i8u
# 15                  uchen@malone.com       olr4zf09x
# 16                  uchen@malone.com       s6escw45g
# 17          robinsoncynthia@dunn.com       wferzj9en
# 18          robinsoncynthia@dunn.com       n5fj5bc0e
# 19      samuel15@saunders-rhodes.com       je76d0ulj
# 20      samuel15@saunders-rhodes.com       dgrnyith9
# 21              johnlowery@gmail.com       8xex97krx
# 22              johnlowery@gmail.com       yxsf33ipw
# 23         jameslandry@rodriguez.com       yk3gx9knx
# 24        ubranch@rivera-parker.info       37264k8rb
# 25            bowenwilliam@yahoo.com       4nt3vg6nr
# 26              ksummers@hotmail.com       anpl44kz2
# 27              ksummers@hotmail.com       12sooz8hm
# 28              ksummers@hotmail.com       ahnb9wv33
# 29              ksummers@hotmail.com       14t4urgqg
# ..                               ...             ...
# 312             johnlowery@gmail.com       8wpdnmsut
# 313             johnlowery@gmail.com       hs3hemcz6
# 314             johnlowery@gmail.com       b001ip7wj
# 315         stevehernandez@gmail.com       8ty2ztfnr
# 316                daniel98@lamb.com       oqkj50e71
# 317              ujackson@harris.com       1phhc3468
# 318              ujackson@harris.com       dby03chrc
# 319          brittanyhicks@jones.com       ti77llxpi
# 320              deborah38@yahoo.com       kzpdmdk05
# 321       andre74@patrick-decker.com       z4jrvn93k
# 322       andre74@patrick-decker.com       sncnkxatz
# 323       andre74@patrick-decker.com       ru0jjkjlt
# 324       andre74@patrick-decker.com       6umtakhhu
# 325        patrickcalderon@russo.net       sptgc1wgt
# 326  mitchellvickie@brewer-jones.com       x644o186l
# 327                sbrown@hughes.biz       wsy5c41nf
# 328                sbrown@hughes.biz       vmktpy2mv
# 329                sbrown@hughes.biz       usu93euvb
# 330             johnlowery@gmail.com       j3foo2l16
# 331             johnlowery@gmail.com       xpd7j7c5g
# 332    ethompson@jackson-sanders.com       b3jl38c9g
# 333    ethompson@jackson-sanders.com       kcg6rzgch
# 334    ethompson@jackson-sanders.com       pj3k9zcc7
# 335    ethompson@jackson-sanders.com       hx496w5tf
# 336    ethompson@jackson-sanders.com       oycs53i0s
# 337    ethompson@jackson-sanders.com       1tmkeoxbm
# 338          dawn05@tucker-brown.com       f0xnu5om9
# 339          dawn05@tucker-brown.com       3zmkegkb8
# 340          dawn05@tucker-brown.com       7yen1m1q8
# 341          dawn05@tucker-brown.com       rh7676yct
#
#      paymentMethodRegistrationFailure paymentMethodType  \
# 0                                True              card
# 1                                True           bitcoin
# 2                               False              card
# 3                               False              card
# 4                               False              card
# 5                               False           bitcoin
# 6                               False              card
# 7                               False              card
# 8                               False              card
# 9                               False              card
# 10                              False              card
# 11                              False         apple pay
# 12                              False         apple pay
# 13                              False         apple pay
# 14                              False              card
# 15                              False              card
# 16                              False              card
# 17                              False            paypal
# 18                              False              card
# 19                              False         apple pay
# 20                              False              card
# 21                              False              card
# 22                              False           bitcoin
# 23                              False              card
# 24                              False            paypal
# 25                              False              card
# 26                              False              card
# 27                              False           bitcoin
# 28                              False              card
# 29                              False              card
# ..                                ...               ...
# 312                             False            paypal
# 313                             False              card
# 314                             False         apple pay
# 315                             False         apple pay
# 316                             False              card
# 317                             False              card
# 318                             False              card
# 319                              True              card
# 320                             False              card
# 321                             False              card
# 322                             False            paypal
# 323                             False              card
# 324                             False         apple pay
# 325                             False         apple pay
# 326                             False              card
# 327                             False              card
# 328                             False              card
# 329                             False              card
# 330                             False              card
# 331                             False              card
# 332                             False              card
# 333                             False              card
# 334                             False           bitcoin
# 335                             False         apple pay
# 336                             False              card
# 337                             False              card
# 338                             False              card
# 339                             False            paypal
# 340                             False              card
# 341                              True         apple pay
#
#            paymentMethodProvider       paymentMethodIssuer
# 0                   JCB 16 digit      Citizens First Banks
# 1                  VISA 16 digit              Solace Banks
# 2                  VISA 16 digit            Vertex Bancorp
# 3    Diners Club / Carte Blanche    His Majesty Bank Corp.
# 4                     Mastercard            Vertex Bancorp
# 5               American Express             Bastion Banks
# 6                        Maestro         Her Majesty Trust
# 7                   JCB 16 digit   Fountain Financial Inc.
# 8                   JCB 16 digit             Bastion Banks
# 9                       Discover    His Majesty Bank Corp.
# 10                       Voyager  Grand Credit Corporation
# 11              American Express  Grand Credit Corporation
# 12                  JCB 16 digit    His Majesty Bank Corp.
# 13                 VISA 16 digit    His Majesty Bank Corp.
# 14                  JCB 16 digit             Bastion Banks
# 15                 VISA 13 digit  Grand Credit Corporation
# 16                  JCB 16 digit              Solace Banks
# 17                  JCB 15 digit                         B
# 18                 VISA 16 digit                         p
# 19                 VISA 13 digit                         x
# 20                  JCB 16 digit                         e
# 21                 VISA 16 digit         Her Majesty Trust
# 22                       Voyager       Bulwark Trust Corp.
# 23                      Discover         Her Majesty Trust
# 24                    Mastercard    His Majesty Bank Corp.
# 25                      Discover                         c
# 26              American Express             Bastion Banks
# 27                       Maestro            Vertex Bancorp
# 28                 VISA 13 digit         Her Majesty Trust
# 29                      Discover            Vertex Bancorp
# ..                           ...                       ...
# 312                 JCB 16 digit            Vertex Bancorp
# 313                      Maestro            Vertex Bancorp
# 314                 JCB 15 digit    His Majesty Bank Corp.
# 315                      Maestro  Grand Credit Corporation
# 316                     Discover  Grand Credit Corporation
# 317                VISA 13 digit       Bulwark Trust Corp.
# 318                   Mastercard           Rose Bancshares
# 319  Diners Club / Carte Blanche       Bulwark Trust Corp.
# 320                VISA 16 digit                         o
# 321                 JCB 16 digit             Bastion Banks
# 322                VISA 16 digit         Her Majesty Trust
# 323                 JCB 16 digit  Grand Credit Corporation
# 324                VISA 16 digit         Her Majesty Trust
# 325             American Express         Her Majesty Trust
# 326                 JCB 16 digit    His Majesty Bank Corp.
# 327                      Voyager                         B
# 328                     Discover                         o
# 329                      Voyager                         x
# 330                 JCB 16 digit            Vertex Bancorp
# 331                 JCB 16 digit   Fountain Financial Inc.
# 332  Diners Club / Carte Blanche             Bastion Banks
# 333                      Maestro      Citizens First Banks
# 334                 JCB 16 digit              Solace Banks
# 335                VISA 16 digit            Vertex Bancorp
# 336                      Voyager      Citizens First Banks
# 337             American Express       Bulwark Trust Corp.
# 338                 JCB 16 digit    His Majesty Bank Corp.
# 339                 JCB 15 digit             Bastion Banks
# 340                VISA 13 digit            Vertex Bancorp
# 341                VISA 13 digit      Citizens First Banks
#
# [342 rows x 6 columns]
